# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from catboost import CatBoostClassifier
from warnings import filterwarnings
import pickle
from tqdm.auto import tqdm
import json

from jeffutils.utils import movecol
from jeffutils import utils

filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %% [markdown]
# <h1>Read in and Process the Data</h1>

# %%
# Read in the data
df = pd.read_feather('./data/play_by_play_full_state_space.feather')
df = df.loc[:, ~df.columns.str.contains('_raw')]

df['home_name'] = df['home_name'].replace({'Montréal Canadiens': 'Montreal Canadiens',
                                           'MontrÃ©al Canadiens': 'Montreal Canadiens'})
df['away_name'] = df['away_name'].replace({'Montréal Canadiens': 'Montreal Canadiens',
                                             'MontrÃ©al Canadiens': 'Montreal Canadiens'})

# Get only the rows with game_date >= 2021-10-01
df_last_two = df[df['game_date'] >= '2018-10-01']

df_train, df_test = df_last_two[df_last_two['game_date'] < '2023-10-01'], df_last_two[df_last_two['game_date'] >= '2023-10-01']

# Drop columns we do not need for XGBoost
drop_columns = ['game_date', 'date_time',
                          'event_type', 'penalty_severity', 'penalty_minutes', 'event_team',
                          'event_team_type', 'period_type', 'period', 'period_seconds',
                          'period_seconds_remaining',
                          'strength_state', 'strength', 'empty_net',
                          'extra_attacker', 'home_skaters', 'away_skaters', 'order',
                          ]

df_train.drop(columns=drop_columns, inplace=True)
df_test.drop(columns=drop_columns, inplace=True)

# Create win column
df_train['win'], df_test['win'] = (df_train['home_final'] > df_train['away_final']).astype(int), (df_test['home_final'] > df_test['away_final']).astype(int)

# %% [markdown]
# <h1>Get Team DataFrame for Training</h1>

# %%
def get_team_df(team_one, df_last_two):
    """
    Generates a DataFrame containing features relevant to team_one's performance 
    and interactions with opponents from previous two seasons.

    Args:
    - team_one (str): Name of the team for which the DataFrame is generated.
    - df_last_two (DataFrame): DataFrame containing data for the last two seasons.

    Returns:
    - DataFrame: A DataFrame with the following columns:
        - 'team': Name of the selected team.
        - 'is_home': Binary indicator if the selected team played at home (1) or away (0).
        - 'curr_strength_code': Current strength code of the selected team.
        - 'curr_goals': Number of goals scored by the selected team in the current match.
        - 'curr_opponent_goals': Number of goals scored by the opponent in the current match.
        - 'win': Binary indicator if the selected team won the current match (1) or not (0).
        - 'team_STATE': Features related to the selected team's performance in various states.
        - 'opponent_STATE': Features related to the opponent's performance in various states.
        - 'opp': Name of the opponent.
        - One-hot encoded columns for opponents and current strength codes.
    """
    
    # Get a subset of the data that just has team_one
    df_team_one = df_last_two[(df_last_two['home_name'] == team_one) | (df_last_two['away_name'] == team_one)]

    # Create a new column called 'opponent' that is the name of the team that team_one is playing
    df_team_one['opponent'] = np.where(df_team_one['home_name'] == team_one, df_team_one['away_name'], df_team_one['home_name'])

    # Create a new column if the selected team is the home team or not
    df_team_one['is_home'] = (df_team_one['home_name'] == team_one).astype(int)
    df_team_one['team'] = team_one

    # Get the scored goals for the selected team
    df_team_one['final_goals'] = np.where(df_team_one['home_name'] == team_one, df_team_one['home_final'], df_team_one['away_final'])

    # Get the scored goals for the opponent
    df_team_one['final_opponent_goals'] = np.where(df_team_one['home_name'] == team_one, df_team_one['away_final'], df_team_one['home_final'])

    # Get the current scored goals for the selected team and the opponent
    df_team_one['curr_goals'] = np.where(df_team_one['home_name'] == team_one, df_team_one['home_score'], df_team_one['away_score'])
    df_team_one['curr_opponent_goals'] = np.where(df_team_one['home_name'] == team_one, df_team_one['away_score'], df_team_one['home_score'])

    # Create home and away strength codes
    df_team_one['home_strength_code'] = df_team_one['strength_code']
    df_team_one['away_strength_code'] = 'EV'
    df_team_one.loc[df_team_one['home_strength_code'] == 'SH', 'away_strength_code'] = 'PP'
    df_team_one.loc[df_team_one['home_strength_code'] == 'PP', 'away_strength_code'] = 'SH'

    # Get the current strength code for the selected
    df_team_one['curr_strength_code'] = np.where(df_team_one['home_name'] == team_one, df_team_one['home_strength_code'], df_team_one['away_strength_code'])

    # Get if the selected team won or not
    # df_team_one.drop(columns=['home_final', 'away_final', win], inplace=True)
    df_team_one['win'] = (df_team_one['final_goals'] > df_team_one['final_opponent_goals']).astype(int)
    df_team_one = movecol(df_team_one, ['team', 'opponent', 'is_home', 'curr_strength_code', 'curr_goals', 'curr_opponent_goals', 'win'], 'strength_code', 'Before')

    # Drop a bunch of columns
    df_team_one.drop(columns=['home_score', 'away_score', 'home_final', 'away_final', 'home_name', 'away_name', 'strength_code',
                            'final_goals', 'final_opponent_goals', 'home_strength_code', 'away_strength_code'], inplace=True)

    # Get all columns with 'STATE_'
    state_columns_pre = df_team_one.columns[df_team_one.columns.str.contains('STATE_')]
    state_columns = list(set(["_".join(state.split('_')[:-1]) for state in state_columns_pre]))
    sorted(state_columns)

    # Iterate through each state getting the appropriate value for the selected team.
    for state in state_columns:
        df_team_one[f"team_{state}"] = np.where(df_team_one['is_home'] == 1, df_team_one[f'{state}_HOME'], df_team_one[f'{state}_AWAY'])

    # Iterate through each state getting the appropriate value for the opponent.
    for state in state_columns:
        df_team_one[f"opponent_{state}"] = np.where(df_team_one['is_home'] == 1, df_team_one[f'{state}_AWAY'], df_team_one[f'{state}_HOME'])    

    # Drop state_columns_pre
    df_team_one.drop(columns=state_columns_pre, inplace=True)

    # one hot opponent
    df_team_one['opp'] = df_team_one['opponent']
    return df_team_one

# %% [markdown]
# <h1>Train CatBoost Model</h1>

# %%
def get_catboost_and_pickle(team_one, df_train, df_test):
    """
    Trains an XGBoost classifier on data for team_one and saves the model as a pickle file.

    Args:
    - team_one (str): Name of the team for which the model is trained.
    - df_last_two (DataFrame): DataFrame containing data for the last two seasons.

    Returns:
    - None: The trained XGBoost model is saved as a pickle file.

    Note:
    This function internally calls the 'get_team_df' function to preprocess the data 
    before training the XGBoost model. The saved model is named after the team.
    """
    # Get the data.
    df_team_one_train = get_team_df(team_one, df_train)
    df_team_one_test = get_team_df(team_one, df_test)
    
    # Get X and y
    X_train = df_team_one_train.drop(columns=['game_id', 'team', 'win', 'opp'])
    y_train = df_team_one_train['win']

    X_test = df_team_one_test.drop(columns=['game_id', 'team', 'win', 'opp'])
    y_test = df_team_one_test['win']
    
    # Grid search parameters
    params = {
        'learning_rate': [0.01, 0.05, 0.1, 0.2],
        'n_estimators': [100, 200, 500, 1000],
        'max_depth': [3, 4, 5, 6, 7],
        'subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
        'colsample_bylevel': [0.6, 0.7, 0.8, 0.9, 1.0],
        'cat_features': [['opponent', 'curr_strength_code']],
        'l2_leaf_reg': [1, 2, 3, 4, 5],
        'min_child_samples': [3, 5, 7, 10],
        'random_seed': [42],  # Keep it constant
        'loss_function': ['Logloss'],  # For binary classification
        'eval_metric': ['AUC'],        # Metric for evaluation
        'verbose': [0]
    }
    
    # Define cross-validation strategy
    cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
    
    # Define the model
    model = CatBoostClassifier()
    
    # Perform GridSearchCV
    grid_search = GridSearchCV(estimator=model, param_grid=params, cv=cv, scoring='accuracy', n_jobs=-1, refit=True)
    grid_search.fit(X_train, y_train)
    test_accuracy = grid_search.score(X_test, y_test)
    
    # Get the best model
    model = grid_search.best_estimator_

    # Save the model
    model.save_model(f'team_catboost_files/{team_one}')
    
    return test_accuracy


# Iterate through each team
pbar = tqdm(total=len(df_last_two['home_name'].unique()))
for team in df_last_two['home_name'].unique():
    if team == 'American All-Stars':
        continue
    res = get_catboost_and_pickle(team, df_train, df_test)
    pbar.update(1)
    pbar.set_description(f'{team} - {res}')
# Out:
#   0%|          | 0/33 [00:00<?, ?it/s]
# 0:	total: 65.5ms	remaining: 6.49s
# 1:	total: 81.4ms	remaining: 3.99s
# 0:	total: 90.2ms	remaining: 8.93s
# 0:	total: 101ms	remaining: 10s
# 1:	total: 145ms	remaining: 7.12s
# 1:	total: 130ms	remaining: 6.35s
# 2:	total: 130ms	remaining: 4.21s
# 0:	total: 116ms	remaining: 11.4s
# 0:	total: 117ms	remaining: 11.6s
# 0:	total: 117ms	remaining: 11.6s
# 0:	total: 121ms	remaining: 12s
# 0:	total: 114ms	remaining: 11.2s
# 1:	total: 167ms	remaining: 8.21s
# 1:	total: 167ms	remaining: 8.2s
# 2:	total: 209ms	remaining: 6.76s
# 3:	total: 201ms	remaining: 4.82s
# 1:	total: 179ms	remaining: 8.78s
# 1:	total: 188ms	remaining: 9.2s
# 1:	total: 205ms	remaining: 10s
# 2:	total: 216ms	remaining: 6.99s
# 3:	total: 284ms	remaining: 6.81s
# 2:	total: 272ms	remaining: 8.79s
# 2:	total: 271ms	remaining: 8.76s
# 2:	total: 284ms	remaining: 9.18s
# 2:	total: 282ms	remaining: 9.12s
# 4:	total: 298ms	remaining: 5.65s
# 3:	total: 297ms	remaining: 7.12s
# 2:	total: 290ms	remaining: 9.38s
# 3:	total: 309ms	remaining: 7.42s
# 3:	total: 321ms	remaining: 7.71s
# 4:	total: 350ms	remaining: 6.64s
# 3:	total: 346ms	remaining: 8.31s
# 5:	total: 366ms	remaining: 5.73s
# 3:	total: 361ms	remaining: 8.66s
# 4:	total: 382ms	remaining: 7.26s
# 5:	total: 400ms	remaining: 6.27s
# 3:	total: 384ms	remaining: 9.22s
# 4:	total: 419ms	remaining: 7.97s
# 4:	total: 426ms	remaining: 8.1s
# 4:	total: 420ms	remaining: 7.97s
# 6:	total: 459ms	remaining: 6.1s
# 6:	total: 479ms	remaining: 6.36s
# 5:	total: 469ms	remaining: 7.35s
# 4:	total: 458ms	remaining: 8.69s
# 4:	total: 458ms	remaining: 8.71s
# 5:	total: 473ms	remaining: 7.41s
# 5:	total: 472ms	remaining: 7.4s
# 5:	total: 474ms	remaining: 7.42s
# 5:	total: 478ms	remaining: 7.48s
# 7:	total: 498ms	remaining: 5.72s
# 7:	total: 517ms	remaining: 5.94s
# 6:	total: 503ms	remaining: 6.68s
# 5:	total: 499ms	remaining: 7.82s
# 6:	total: 528ms	remaining: 7.01s
# 6:	total: 522ms	remaining: 6.94s
# 6:	total: 527ms	remaining: 7.01s
# 6:	total: 534ms	remaining: 7.09s
# 7:	total: 554ms	remaining: 6.37s
# 8:	total: 560ms	remaining: 5.66s
# 6:	total: 537ms	remaining: 7.13s
# 7:	total: 557ms	remaining: 6.4s
# 7:	total: 569ms	remaining: 6.54s
# 9:	total: 592ms	remaining: 5.33s
# 7:	total: 583ms	remaining: 6.71s
# 8:	total: 610ms	remaining: 6.17s
# 7:	total: 581ms	remaining: 6.68s
# 7:	total: 589ms	remaining: 6.77s
# 8:	total: 628ms	remaining: 6.35s
# 8:	total: 631ms	remaining: 6.38s
# 8:	total: 633ms	remaining: 6.4s
# 10:	total: 647ms	remaining: 5.24s
# 8:	total: 640ms	remaining: 6.47s
# 8:	total: 635ms	remaining: 6.42s
# 9:	total: 691ms	remaining: 6.22s
# 11:	total: 677ms	remaining: 4.96s
# 9:	total: 665ms	remaining: 5.98s
# 8:	total: 656ms	remaining: 6.63s
# 9:	total: 685ms	remaining: 6.17s
# 9:	total: 674ms	remaining: 6.06s
# 9:	total: 685ms	remaining: 6.17s
# 9:	total: 685ms	remaining: 6.16s
# 10:	total: 708ms	remaining: 5.72s
# 12:	total: 707ms	remaining: 4.73s
# 10:	total: 732ms	remaining: 5.92s
# 10:	total: 706ms	remaining: 5.71s
# 9:	total: 700ms	remaining: 6.3s
# 10:	total: 717ms	remaining: 5.8s
# 10:	total: 721ms	remaining: 5.83s
# 13:	total: 740ms	remaining: 4.54s
# 10:	total: 731ms	remaining: 5.91s
# 11:	total: 770ms	remaining: 5.64s
# 11:	total: 756ms	remaining: 5.54s
# 11:	total: 747ms	remaining: 5.48s
# 11:	total: 750ms	remaining: 5.5s
# 10:	total: 750ms	remaining: 6.06s
# 11:	total: 764ms	remaining: 5.61s
# 12:	total: 782ms	remaining: 5.23s
# 11:	total: 772ms	remaining: 5.66s
# 14:	total: 783ms	remaining: 4.43s
# 12:	total: 803ms	remaining: 5.37s
# 12:	total: 787ms	remaining: 5.27s
# 12:	total: 794ms	remaining: 5.31s
# 15:	total: 814ms	remaining: 4.27s
# 11:	total: 790ms	remaining: 5.79s
# 12:	total: 803ms	remaining: 5.37s
# 13:	total: 837ms	remaining: 5.14s
# 13:	total: 816ms	remaining: 5.01s
# 12:	total: 819ms	remaining: 5.48s
# 13:	total: 836ms	remaining: 5.14s
# 16:	total: 848ms	remaining: 4.14s
# 13:	total: 848ms	remaining: 5.21s
# 14:	total: 887ms	remaining: 5.03s
# 14:	total: 881ms	remaining: 4.99s
# 14:	total: 870ms	remaining: 4.93s
# 13:	total: 870ms	remaining: 5.34s
# 17:	total: 888ms	remaining: 4.04s
# 13:	total: 881ms	remaining: 5.41s
# 15:	total: 929ms	remaining: 4.88s
# 12:	total: 887ms	remaining: 5.94s
# 15:	total: 917ms	remaining: 4.82s
# 15:	total: 919ms	remaining: 4.82s
# 18:	total: 937ms	remaining: 3.99s
# 16:	total: 949ms	remaining: 4.63s
# 16:	total: 968ms	remaining: 4.73s
# 14:	total: 953ms	remaining: 5.4s
# 16:	total: 957ms	remaining: 4.67s
# 14:	total: 959ms	remaining: 5.43s
# 14:	total: 968ms	remaining: 5.48s
# 19:	total: 988ms	remaining: 3.95s
# 13:	total: 964ms	remaining: 5.92s
# 17:	total: 993ms	remaining: 4.52s
# 15:	total: 992ms	remaining: 5.21s
# 17:	total: 1s	remaining: 4.56s
# 15:	total: 1.01s	remaining: 5.31s
# 18:	total: 1.04s	remaining: 4.43s
# 18:	total: 1.03s	remaining: 4.38s
# 20:	total: 1.04s	remaining: 3.92s
# 15:	total: 1.03s	remaining: 5.4s
# 16:	total: 1.04s	remaining: 5.07s
# 17:	total: 1.07s	remaining: 4.89s
# 19:	total: 1.07s	remaining: 4.3s
# 14:	total: 1.05s	remaining: 5.98s
# 16:	total: 1.07s	remaining: 5.22s
# 19:	total: 1.07s	remaining: 4.3s
# 16:	total: 1.07s	remaining: 5.23s
# 21:	total: 1.09s	remaining: 3.86s
# 17:	total: 1.09s	remaining: 4.96s
# 22:	total: 1.12s	remaining: 3.74s
# 17:	total: 1.11s	remaining: 5.04s
# 18:	total: 1.14s	remaining: 4.86s
# 20:	total: 1.14s	remaining: 4.27s
# 17:	total: 1.13s	remaining: 5.13s
# 18:	total: 1.13s	remaining: 4.81s
# 20:	total: 1.14s	remaining: 4.27s
# 18:	total: 1.15s	remaining: 4.9s
# 15:	total: 1.14s	remaining: 5.99s
# 19:	total: 1.19s	remaining: 4.74s
# 21:	total: 1.16s	remaining: 4.11s
# 23:	total: 1.17s	remaining: 3.71s
# 18:	total: 1.16s	remaining: 4.94s
# 21:	total: 1.19s	remaining: 4.21s
# 20:	total: 1.2s	remaining: 4.53s
# 19:	total: 1.17s	remaining: 4.7s
# 16:	total: 1.17s	remaining: 5.69s
# 19:	total: 1.18s	remaining: 4.72s
# 24:	total: 1.22s	remaining: 3.65s
# 19:	total: 1.21s	remaining: 4.82s
# 22:	total: 1.22s	remaining: 4.07s
# 20:	total: 1.21s	remaining: 4.56s
# 20:	total: 1.21s	remaining: 4.57s
# 22:	total: 1.23s	remaining: 4.13s
# 21:	total: 1.26s	remaining: 4.48s
# 20:	total: 1.23s	remaining: 4.64s
# 23:	total: 1.24s	remaining: 3.92s
# 17:	total: 1.23s	remaining: 5.59s
# 25:	total: 1.26s	remaining: 3.58s
# 23:	total: 1.27s	remaining: 4.04s
# 22:	total: 1.3s	remaining: 4.35s
# 26:	total: 1.29s	remaining: 3.48s
# 18:	total: 1.26s	remaining: 5.39s
# 24:	total: 1.28s	remaining: 3.84s
# 21:	total: 1.28s	remaining: 4.53s
# 21:	total: 1.28s	remaining: 4.53s
# 21:	total: 1.3s	remaining: 4.62s
# 24:	total: 1.32s	remaining: 3.96s
# 27:	total: 1.33s	remaining: 3.41s
# 19:	total: 1.3s	remaining: 5.21s
# 23:	total: 1.35s	remaining: 4.27s
# 25:	total: 1.33s	remaining: 3.78s
# 22:	total: 1.34s	remaining: 4.48s
# 22:	total: 1.34s	remaining: 4.48s
# 22:	total: 1.34s	remaining: 4.5s
# 20:	total: 1.33s	remaining: 5.03s
# 24:	total: 1.38s	remaining: 4.14s
# 28:	total: 1.36s	remaining: 3.34s
# 26:	total: 1.35s	remaining: 3.66s
# 25:	total: 1.37s	remaining: 3.91s
# 23:	total: 1.37s	remaining: 4.33s
# 21:	total: 1.36s	remaining: 4.83s
# 23:	total: 1.38s	remaining: 4.38s
# 29:	total: 1.4s	remaining: 3.26s
# 23:	total: 1.38s	remaining: 4.38s
# 25:	total: 1.42s	remaining: 4.03s
# 26:	total: 1.41s	remaining: 3.82s
# 27:	total: 1.41s	remaining: 3.62s
# 22:	total: 1.4s	remaining: 4.67s
# 26:	total: 1.44s	remaining: 3.91s
# 24:	total: 1.41s	remaining: 4.24s
# 24:	total: 1.42s	remaining: 4.25s
# 24:	total: 1.43s	remaining: 4.28s
# 28:	total: 1.44s	remaining: 3.53s
# 25:	total: 1.44s	remaining: 4.1s
# 23:	total: 1.43s	remaining: 4.52s
# 30:	total: 1.45s	remaining: 3.23s
# 27:	total: 1.48s	remaining: 3.81s
# 25:	total: 1.45s	remaining: 4.13s
# 27:	total: 1.47s	remaining: 3.77s
# 25:	total: 1.46s	remaining: 4.15s
# 26:	total: 1.47s	remaining: 3.97s
# 24:	total: 1.47s	remaining: 4.4s
# 31:	total: 1.49s	remaining: 3.17s
# 29:	total: 1.48s	remaining: 3.46s
# 28:	total: 1.51s	remaining: 3.71s
# 28:	total: 1.51s	remaining: 3.71s
# 26:	total: 1.5s	remaining: 4.07s
# 32:	total: 1.52s	remaining: 3.09s
# 29:	total: 1.55s	remaining: 3.62s
# 27:	total: 1.52s	remaining: 3.92s
# 26:	total: 1.53s	remaining: 4.13s
# 29:	total: 1.55s	remaining: 3.61s
# 30:	total: 1.54s	remaining: 3.42s
# 25:	total: 1.53s	remaining: 4.34s
# 27:	total: 1.54s	remaining: 3.97s
# 28:	total: 1.57s	remaining: 3.84s
# 30:	total: 1.6s	remaining: 3.56s
# 33:	total: 1.58s	remaining: 3.07s
# 31:	total: 1.58s	remaining: 3.35s
# 28:	total: 1.58s	remaining: 3.86s
# 27:	total: 1.58s	remaining: 4.07s
# 34:	total: 1.6s	remaining: 2.98s
# 26:	total: 1.58s	remaining: 4.28s
# 30:	total: 1.61s	remaining: 3.58s
# 31:	total: 1.63s	remaining: 3.46s
# 29:	total: 1.6s	remaining: 3.74s
# 32:	total: 1.61s	remaining: 3.27s
# 35:	total: 1.63s	remaining: 2.89s
# 31:	total: 1.63s	remaining: 3.47s
# 29:	total: 1.62s	remaining: 3.79s
# 32:	total: 1.66s	remaining: 3.37s
# 28:	total: 1.63s	remaining: 3.99s
# 30:	total: 1.64s	remaining: 3.65s
# 36:	total: 1.66s	remaining: 2.82s
# 33:	total: 1.65s	remaining: 3.21s
# 32:	total: 1.67s	remaining: 3.4s
# 27:	total: 1.65s	remaining: 4.23s
# 30:	total: 1.67s	remaining: 3.71s
# 29:	total: 1.67s	remaining: 3.9s
# 33:	total: 1.7s	remaining: 3.31s
# 31:	total: 1.68s	remaining: 3.56s
# 37:	total: 1.7s	remaining: 2.77s
# 34:	total: 1.7s	remaining: 3.15s
# 28:	total: 1.68s	remaining: 4.13s
# 33:	total: 1.71s	remaining: 3.33s
# 34:	total: 1.73s	remaining: 3.22s
# 30:	total: 1.7s	remaining: 3.79s
# 31:	total: 1.71s	remaining: 3.64s
# 32:	total: 1.72s	remaining: 3.49s
# 29:	total: 1.71s	remaining: 3.99s
# 38:	total: 1.74s	remaining: 2.72s
# 31:	total: 1.73s	remaining: 3.67s
# 35:	total: 1.73s	remaining: 3.08s
# 33:	total: 1.75s	remaining: 3.4s
# 30:	total: 1.74s	remaining: 3.87s
# 32:	total: 1.75s	remaining: 3.55s
# 35:	total: 1.78s	remaining: 3.17s
# 34:	total: 1.77s	remaining: 3.28s
# 36:	total: 1.76s	remaining: 3s
# 39:	total: 1.79s	remaining: 2.68s
# 31:	total: 1.77s	remaining: 3.76s
# 34:	total: 1.78s	remaining: 3.31s
# 35:	total: 1.8s	remaining: 3.2s
# 33:	total: 1.78s	remaining: 3.46s
# 32:	total: 1.78s	remaining: 3.62s
# 37:	total: 1.79s	remaining: 2.92s
# 36:	total: 1.83s	remaining: 3.11s
# 35:	total: 1.81s	remaining: 3.23s
# 36:	total: 1.83s	remaining: 3.12s
# 32:	total: 1.81s	remaining: 3.68s
# 34:	total: 1.83s	remaining: 3.4s
# 33:	total: 1.83s	remaining: 3.56s
# 38:	total: 1.84s	remaining: 2.88s
# 40:	total: 1.85s	remaining: 2.67s
# 37:	total: 1.88s	remaining: 3.06s
# 37:	total: 1.88s	remaining: 3.07s
# 33:	total: 1.85s	remaining: 3.6s
# 36:	total: 1.87s	remaining: 3.19s
# 35:	total: 1.88s	remaining: 3.34s
# 39:	total: 1.89s	remaining: 2.83s
# 34:	total: 1.9s	remaining: 3.52s
# 36:	total: 1.9s	remaining: 3.24s
# 40:	total: 1.92s	remaining: 2.76s
# 38:	total: 1.93s	remaining: 3.02s
# 37:	total: 1.92s	remaining: 3.13s
# 38:	total: 1.95s	remaining: 3.05s
# 35:	total: 1.92s	remaining: 3.42s
# 34:	total: 1.91s	remaining: 3.55s
# 41:	total: 1.94s	remaining: 2.68s
# 37:	total: 1.94s	remaining: 3.17s
# 39:	total: 1.98s	remaining: 2.96s
# 36:	total: 1.96s	remaining: 3.33s
# 38:	total: 1.96s	remaining: 3.07s
# 39:	total: 1.98s	remaining: 2.97s
# 35:	total: 1.95s	remaining: 3.47s
# 41:	total: 1.97s	remaining: 2.72s
# 38:	total: 1.98s	remaining: 3.09s
# 40:	total: 2.01s	remaining: 2.89s
# 42:	total: 2s	remaining: 2.65s
# 42:	total: 2s	remaining: 2.65s
# 40:	total: 2.01s	remaining: 2.9s
# 37:	total: 2s	remaining: 3.26s
# 39:	total: 2.02s	remaining: 3.03s
# 36:	total: 2.01s	remaining: 3.42s
# 43:	total: 2.02s	remaining: 2.58s
# 39:	total: 2.02s	remaining: 3.03s
# 41:	total: 2.04s	remaining: 2.82s
# 43:	total: 2.04s	remaining: 2.59s
# 38:	total: 2.03s	remaining: 3.17s
# 37:	total: 2.04s	remaining: 3.32s
# 41:	total: 2.08s	remaining: 2.87s
# 44:	total: 2.05s	remaining: 2.51s
# 40:	total: 2.06s	remaining: 2.96s
# 39:	total: 2.06s	remaining: 3.08s
# 40:	total: 2.06s	remaining: 2.96s
# 42:	total: 2.08s	remaining: 2.76s
# 38:	total: 2.06s	remaining: 3.23s
# 42:	total: 2.11s	remaining: 2.8s
# 44:	total: 2.09s	remaining: 2.56s
# 41:	total: 2.09s	remaining: 2.89s
# 41:	total: 2.09s	remaining: 2.89s
# 45:	total: 2.1s	remaining: 2.47s
# 40:	total: 2.11s	remaining: 3.04s
# 43:	total: 2.14s	remaining: 2.73s
# 45:	total: 2.13s	remaining: 2.5s
# 43:	total: 2.13s	remaining: 2.72s
# 42:	total: 2.14s	remaining: 2.83s
# 39:	total: 2.13s	remaining: 3.19s
# 42:	total: 2.14s	remaining: 2.84s
# 41:	total: 2.15s	remaining: 2.97s
# 46:	total: 2.16s	remaining: 2.43s
# 46:	total: 2.17s	remaining: 2.44s
# 40:	total: 2.15s	remaining: 3.09s
# 44:	total: 2.17s	remaining: 2.65s
# 43:	total: 2.16s	remaining: 2.75s
# 47:	total: 2.19s	remaining: 2.37s
# 43:	total: 2.19s	remaining: 2.78s
# 41:	total: 2.18s	remaining: 3.01s
# 45:	total: 2.21s	remaining: 2.59s
# 42:	total: 2.19s	remaining: 2.91s
# 44:	total: 2.23s	remaining: 2.73s
# 48:	total: 2.22s	remaining: 2.31s
# 42:	total: 2.2s	remaining: 2.92s
# 46:	total: 2.23s	remaining: 2.52s
# 44:	total: 2.22s	remaining: 2.72s
# 47:	total: 2.23s	remaining: 2.42s
# 45:	total: 2.26s	remaining: 2.65s
# 44:	total: 2.23s	remaining: 2.72s
# 43:	total: 2.23s	remaining: 2.84s
# 45:	total: 2.25s	remaining: 2.64s
# 43:	total: 2.24s	remaining: 2.85s
# 48:	total: 2.27s	remaining: 2.36s
# 49:	total: 2.27s	remaining: 2.27s
# 46:	total: 2.29s	remaining: 2.59s
# 45:	total: 2.27s	remaining: 2.67s
# 44:	total: 2.27s	remaining: 2.77s
# 47:	total: 2.29s	remaining: 2.48s
# 50:	total: 2.29s	remaining: 2.2s
# 44:	total: 2.29s	remaining: 2.8s
# 46:	total: 2.3s	remaining: 2.59s
# 46:	total: 2.3s	remaining: 2.59s
# 45:	total: 2.29s	remaining: 2.69s
# 49:	total: 2.31s	remaining: 2.31s
# 48:	total: 2.32s	remaining: 2.42s
# 47:	total: 2.35s	remaining: 2.54s
# 47:	total: 2.33s	remaining: 2.53s
# 45:	total: 2.33s	remaining: 2.74s
# 47:	total: 2.34s	remaining: 2.53s
# 51:	total: 2.35s	remaining: 2.16s
# 50:	total: 2.35s	remaining: 2.26s
# 46:	total: 2.33s	remaining: 2.63s
# 49:	total: 2.36s	remaining: 2.36s
# 48:	total: 2.39s	remaining: 2.49s
# 46:	total: 2.37s	remaining: 2.67s
# 52:	total: 2.37s	remaining: 2.1s
# 50:	total: 2.38s	remaining: 2.29s
# 48:	total: 2.38s	remaining: 2.48s
# 48:	total: 2.39s	remaining: 2.49s
# 47:	total: 2.38s	remaining: 2.58s
# 51:	total: 2.4s	remaining: 2.22s
# 49:	total: 2.43s	remaining: 2.43s
# 51:	total: 2.42s	remaining: 2.23s
# 47:	total: 2.41s	remaining: 2.61s
# 53:	total: 2.42s	remaining: 2.06s
# 49:	total: 2.42s	remaining: 2.42s
# 49:	total: 2.43s	remaining: 2.43s
# 48:	total: 2.42s	remaining: 2.52s
# 52:	total: 2.45s	remaining: 2.17s
# 50:	total: 2.47s	remaining: 2.38s
# 48:	total: 2.44s	remaining: 2.54s
# 50:	total: 2.44s	remaining: 2.35s
# 52:	total: 2.46s	remaining: 2.18s
# 49:	total: 2.47s	remaining: 2.47s
# 50:	total: 2.47s	remaining: 2.37s
# 54:	total: 2.48s	remaining: 2.02s
# 49:	total: 2.46s	remaining: 2.46s
# 51:	total: 2.48s	remaining: 2.29s
# 53:	total: 2.49s	remaining: 2.12s
# 53:	total: 2.5s	remaining: 2.13s
# 50:	total: 2.49s	remaining: 2.39s
# 51:	total: 2.54s	remaining: 2.34s
# 50:	total: 2.5s	remaining: 2.4s
# 54:	total: 2.53s	remaining: 2.07s
# 54:	total: 2.53s	remaining: 2.07s
# 55:	total: 2.53s	remaining: 1.99s
# 51:	total: 2.53s	remaining: 2.33s
# 52:	total: 2.57s	remaining: 2.28s
# 51:	total: 2.54s	remaining: 2.35s
# 52:	total: 2.55s	remaining: 2.26s
# 55:	total: 2.56s	remaining: 2.01s
# 51:	total: 2.54s	remaining: 2.35s
# 56:	total: 2.56s	remaining: 1.93s
# 53:	total: 2.6s	remaining: 2.21s
# 52:	total: 2.57s	remaining: 2.28s
# 57:	total: 2.58s	remaining: 1.87s
# 55:	total: 2.6s	remaining: 2.04s
# 56:	total: 2.6s	remaining: 1.96s
# 52:	total: 2.59s	remaining: 2.29s
# 53:	total: 2.59s	remaining: 2.21s
# 53:	total: 2.6s	remaining: 2.21s
# 56:	total: 2.62s	remaining: 1.98s
# 54:	total: 2.64s	remaining: 2.16s
# 57:	total: 2.63s	remaining: 1.9s
# 52:	total: 2.61s	remaining: 2.31s
# 54:	total: 2.62s	remaining: 2.15s
# 54:	total: 2.63s	remaining: 2.15s
# 53:	total: 2.63s	remaining: 2.24s
# 58:	total: 2.63s	remaining: 1.83s
# 57:	total: 2.66s	remaining: 1.93s
# 55:	total: 2.68s	remaining: 2.11s
# 55:	total: 2.65s	remaining: 2.08s
# 53:	total: 2.64s	remaining: 2.25s
# 59:	total: 2.67s	remaining: 1.78s
# 58:	total: 2.68s	remaining: 1.86s
# 55:	total: 2.68s	remaining: 2.1s
# 54:	total: 2.68s	remaining: 2.19s
# 58:	total: 2.69s	remaining: 1.87s
# 54:	total: 2.68s	remaining: 2.19s
# 56:	total: 2.69s	remaining: 2.03s
# 56:	total: 2.72s	remaining: 2.06s
# 60:	total: 2.7s	remaining: 1.73s
# 59:	total: 2.72s	remaining: 1.81s
# 56:	total: 2.71s	remaining: 2.04s
# 55:	total: 2.71s	remaining: 2.13s
# 59:	total: 2.73s	remaining: 1.82s
# 55:	total: 2.71s	remaining: 2.13s
# 57:	total: 2.73s	remaining: 1.98s
# 61:	total: 2.74s	remaining: 1.68s
# 56:	total: 2.73s	remaining: 2.06s
# 57:	total: 2.77s	remaining: 2.01s
# 57:	total: 2.75s	remaining: 1.99s
# 60:	total: 2.76s	remaining: 1.76s
# 58:	total: 2.76s	remaining: 1.92s
# 57:	total: 2.76s	remaining: 2s
# 56:	total: 2.75s	remaining: 2.08s
# 60:	total: 2.79s	remaining: 1.78s
# 61:	total: 2.79s	remaining: 1.71s
# 58:	total: 2.81s	remaining: 1.95s
# 58:	total: 2.78s	remaining: 1.93s
# 62:	total: 2.79s	remaining: 1.64s
# 57:	total: 2.79s	remaining: 2.02s
# 59:	total: 2.84s	remaining: 1.89s
# 61:	total: 2.83s	remaining: 1.73s
# 59:	total: 2.81s	remaining: 1.88s
# 58:	total: 2.82s	remaining: 1.96s
# 59:	total: 2.82s	remaining: 1.88s
# 62:	total: 2.83s	remaining: 1.66s
# 63:	total: 2.82s	remaining: 1.59s
# 58:	total: 2.81s	remaining: 1.95s
# 63:	total: 2.86s	remaining: 1.61s
# 60:	total: 2.88s	remaining: 1.84s
# 60:	total: 2.85s	remaining: 1.82s
# 59:	total: 2.84s	remaining: 1.9s
# 62:	total: 2.87s	remaining: 1.69s
# 59:	total: 2.86s	remaining: 1.9s
# 64:	total: 2.86s	remaining: 1.54s
# 60:	total: 2.87s	remaining: 1.83s
# 64:	total: 2.88s	remaining: 1.55s
# 61:	total: 2.91s	remaining: 1.78s
# 63:	total: 2.9s	remaining: 1.63s
# 61:	total: 2.89s	remaining: 1.77s
# 60:	total: 2.89s	remaining: 1.85s
# 65:	total: 2.91s	remaining: 1.5s
# 64:	total: 2.93s	remaining: 1.57s
# 61:	total: 2.92s	remaining: 1.79s
# 62:	total: 2.96s	remaining: 1.74s
# 60:	total: 2.92s	remaining: 1.86s
# 61:	total: 2.93s	remaining: 1.8s
# 62:	total: 2.93s	remaining: 1.72s
# 65:	total: 2.94s	remaining: 1.51s
# 66:	total: 2.95s	remaining: 1.45s
# 63:	total: 2.98s	remaining: 1.68s
# 63:	total: 2.96s	remaining: 1.66s
# 65:	total: 2.97s	remaining: 1.53s
# 62:	total: 2.96s	remaining: 1.74s
# 61:	total: 2.95s	remaining: 1.81s
# 62:	total: 2.97s	remaining: 1.75s
# 66:	total: 2.98s	remaining: 1.47s
# 67:	total: 2.99s	remaining: 1.41s
# 64:	total: 3.02s	remaining: 1.63s
# 63:	total: 2.99s	remaining: 1.68s
# 64:	total: 3s	remaining: 1.61s
# 66:	total: 3.01s	remaining: 1.48s
# 62:	total: 3s	remaining: 1.76s
# 67:	total: 3.03s	remaining: 1.43s
# 68:	total: 3.03s	remaining: 1.36s
# 67:	total: 3.03s	remaining: 1.43s
# 64:	total: 3.02s	remaining: 1.63s
# 63:	total: 3.03s	remaining: 1.7s
# 65:	total: 3.06s	remaining: 1.58s
# 65:	total: 3.03s	remaining: 1.56s
# 63:	total: 3.03s	remaining: 1.7s
# 68:	total: 3.06s	remaining: 1.37s
# 69:	total: 3.07s	remaining: 1.31s
# 68:	total: 3.08s	remaining: 1.38s
# 66:	total: 3.1s	remaining: 1.53s
# 64:	total: 3.08s	remaining: 1.66s
# 65:	total: 3.08s	remaining: 1.58s
# 66:	total: 3.08s	remaining: 1.51s
# 69:	total: 3.08s	remaining: 1.32s
# 70:	total: 3.1s	remaining: 1.26s
# 64:	total: 3.08s	remaining: 1.66s
# 66:	total: 3.1s	remaining: 1.53s
# 69:	total: 3.12s	remaining: 1.33s
# 70:	total: 3.11s	remaining: 1.27s
# 65:	total: 3.12s	remaining: 1.61s
# 70:	total: 3.14s	remaining: 1.28s
# 65:	total: 3.12s	remaining: 1.61s
# 71:	total: 3.14s	remaining: 1.22s
# 67:	total: 3.16s	remaining: 1.49s
# 71:	total: 3.14s	remaining: 1.22s
# 67:	total: 3.14s	remaining: 1.48s
# 67:	total: 3.14s	remaining: 1.48s
# 66:	total: 3.15s	remaining: 1.55s
# 71:	total: 3.17s	remaining: 1.23s
# 66:	total: 3.16s	remaining: 1.56s
# 68:	total: 3.18s	remaining: 1.43s
# 68:	total: 3.21s	remaining: 1.44s
# 68:	total: 3.18s	remaining: 1.43s
# 72:	total: 3.18s	remaining: 1.18s
# 67:	total: 3.19s	remaining: 1.5s
# 72:	total: 3.2s	remaining: 1.18s
# 69:	total: 3.2s	remaining: 1.37s
# 72:	total: 3.21s	remaining: 1.19s
# 68:	total: 3.21s	remaining: 1.44s
# 73:	total: 3.22s	remaining: 1.13s
# 67:	total: 3.21s	remaining: 1.51s
# 73:	total: 3.23s	remaining: 1.13s
# 69:	total: 3.22s	remaining: 1.38s
# 69:	total: 3.25s	remaining: 1.4s
# 73:	total: 3.24s	remaining: 1.14s
# 69:	total: 3.25s	remaining: 1.39s
# 70:	total: 3.25s	remaining: 1.33s
# 74:	total: 3.26s	remaining: 1.09s
# 74:	total: 3.27s	remaining: 1.09s
# 70:	total: 3.26s	remaining: 1.33s
# 74:	total: 3.28s	remaining: 1.09s
# 68:	total: 3.25s	remaining: 1.46s
# 70:	total: 3.29s	remaining: 1.35s
# 71:	total: 3.29s	remaining: 1.28s
# 75:	total: 3.29s	remaining: 1.04s
# 71:	total: 3.29s	remaining: 1.28s
# 70:	total: 3.29s	remaining: 1.34s
# 69:	total: 3.3s	remaining: 1.42s
# 75:	total: 3.32s	remaining: 1.05s
# 76:	total: 3.32s	remaining: 992ms
# 72:	total: 3.32s	remaining: 1.23s
# 71:	total: 3.36s	remaining: 1.3s
# 75:	total: 3.34s	remaining: 1.05s
# 71:	total: 3.33s	remaining: 1.3s
# 72:	total: 3.34s	remaining: 1.23s
# 76:	total: 3.35s	remaining: 1s
# 77:	total: 3.36s	remaining: 947ms
# 72:	total: 3.39s	remaining: 1.25s
# 73:	total: 3.36s	remaining: 1.18s
# 70:	total: 3.36s	remaining: 1.37s
# 77:	total: 3.38s	remaining: 953ms
# 76:	total: 3.39s	remaining: 1.01s
# 72:	total: 3.37s	remaining: 1.25s
# 73:	total: 3.38s	remaining: 1.19s
# 73:	total: 3.41s	remaining: 1.2s
# 73:	total: 3.4s	remaining: 1.19s
# 71:	total: 3.39s	remaining: 1.32s
# 77:	total: 3.42s	remaining: 965ms
# 78:	total: 3.42s	remaining: 908ms
# 78:	total: 3.41s	remaining: 908ms
# 74:	total: 3.43s	remaining: 1.14s
# 74:	total: 3.46s	remaining: 1.16s
# 74:	total: 3.44s	remaining: 1.15s
# 78:	total: 3.45s	remaining: 917ms
# 74:	total: 3.44s	remaining: 1.15s
# 79:	total: 3.45s	remaining: 862ms
# 79:	total: 3.45s	remaining: 862ms
# 72:	total: 3.43s	remaining: 1.27s
# 75:	total: 3.49s	remaining: 1.1s
# 79:	total: 3.48s	remaining: 871ms
# 75:	total: 3.48s	remaining: 1.1s
# 80:	total: 3.48s	remaining: 817ms
# 75:	total: 3.48s	remaining: 1.1s
# 75:	total: 3.48s	remaining: 1.1s
# 80:	total: 3.49s	remaining: 819ms
# 73:	total: 3.47s	remaining: 1.22s
# 80:	total: 3.52s	remaining: 825ms
# 76:	total: 3.51s	remaining: 1.05s
# 74:	total: 3.5s	remaining: 1.17s
# 76:	total: 3.55s	remaining: 1.06s
# 81:	total: 3.53s	remaining: 775ms
# 81:	total: 3.54s	remaining: 777ms
# 81:	total: 3.55s	remaining: 779ms
# 76:	total: 3.54s	remaining: 1.06s
# 77:	total: 3.54s	remaining: 999ms
# 76:	total: 3.54s	remaining: 1.06s
# 77:	total: 3.58s	remaining: 1.01s
# 75:	total: 3.54s	remaining: 1.12s
# 77:	total: 3.56s	remaining: 1s
# 82:	total: 3.57s	remaining: 732ms
# 82:	total: 3.58s	remaining: 734ms
# 78:	total: 3.58s	remaining: 952ms
# 76:	total: 3.57s	remaining: 1.07s
# 82:	total: 3.6s	remaining: 737ms
# 77:	total: 3.59s	remaining: 1.01s
# 78:	total: 3.6s	remaining: 956ms
# 78:	total: 3.63s	remaining: 965ms
# 83:	total: 3.61s	remaining: 688ms
# 83:	total: 3.63s	remaining: 691ms
# 83:	total: 3.63s	remaining: 692ms
# 77:	total: 3.62s	remaining: 1.02s
# 78:	total: 3.63s	remaining: 966ms
# 79:	total: 3.63s	remaining: 908ms
# 84:	total: 3.64s	remaining: 643ms
# 79:	total: 3.64s	remaining: 909ms
# 79:	total: 3.67s	remaining: 918ms
# 84:	total: 3.66s	remaining: 645ms
# 78:	total: 3.65s	remaining: 970ms
# 79:	total: 3.66s	remaining: 916ms
# 84:	total: 3.68s	remaining: 649ms
# 80:	total: 3.67s	remaining: 862ms
# 80:	total: 3.68s	remaining: 863ms
# 85:	total: 3.69s	remaining: 600ms
# 85:	total: 3.69s	remaining: 601ms
# 79:	total: 3.68s	remaining: 919ms
# 80:	total: 3.72s	remaining: 873ms
# 81:	total: 3.71s	remaining: 814ms
# 86:	total: 3.72s	remaining: 555ms
# 80:	total: 3.7s	remaining: 867ms
# 80:	total: 3.71s	remaining: 871ms
# 85:	total: 3.72s	remaining: 605ms
# 86:	total: 3.73s	remaining: 557ms
# 81:	total: 3.75s	remaining: 823ms
# 81:	total: 3.73s	remaining: 818ms
# 87:	total: 3.75s	remaining: 511ms
# 82:	total: 3.75s	remaining: 768ms
# 81:	total: 3.76s	remaining: 825ms
# 87:	total: 3.77s	remaining: 514ms
# 81:	total: 3.76s	remaining: 826ms
# 82:	total: 3.76s	remaining: 771ms
# 83:	total: 3.78s	remaining: 720ms
# 88:	total: 3.79s	remaining: 468ms
# 86:	total: 3.79s	remaining: 566ms
# 82:	total: 3.79s	remaining: 776ms
# 82:	total: 3.82s	remaining: 782ms
# 83:	total: 3.79s	remaining: 723ms
# 88:	total: 3.82s	remaining: 472ms
# 89:	total: 3.82s	remaining: 424ms
# 83:	total: 3.85s	remaining: 733ms
# 87:	total: 3.82s	remaining: 521ms
# 82:	total: 3.82s	remaining: 782ms
# 84:	total: 3.83s	remaining: 675ms
# 88:	total: 3.84s	remaining: 475ms
# 89:	total: 3.85s	remaining: 428ms
# 84:	total: 3.88s	remaining: 684ms
# 84:	total: 3.84s	remaining: 678ms
# 90:	total: 3.86s	remaining: 382ms
# 83:	total: 3.86s	remaining: 735ms
# 85:	total: 3.86s	remaining: 629ms
# 91:	total: 3.89s	remaining: 338ms
# 84:	total: 3.88s	remaining: 686ms
# 83:	total: 3.89s	remaining: 740ms
# 85:	total: 3.88s	remaining: 631ms
# 90:	total: 3.9s	remaining: 386ms
# 85:	total: 3.93s	remaining: 639ms
# 89:	total: 3.91s	remaining: 434ms
# 92:	total: 3.92s	remaining: 295ms
# 91:	total: 3.93s	remaining: 342ms
# 85:	total: 3.92s	remaining: 638ms
# 86:	total: 3.92s	remaining: 586ms
# 86:	total: 3.92s	remaining: 586ms
# 92:	total: 3.95s	remaining: 297ms
# 84:	total: 3.94s	remaining: 695ms
# 86:	total: 3.97s	remaining: 594ms
# 90:	total: 3.95s	remaining: 391ms
# 87:	total: 3.95s	remaining: 539ms
# 93:	total: 3.96s	remaining: 253ms
# 86:	total: 3.97s	remaining: 593ms
# 87:	total: 3.97s	remaining: 541ms
# 88:	total: 3.98s	remaining: 492ms
# 94:	total: 3.99s	remaining: 210ms
# 85:	total: 3.99s	remaining: 649ms
# 93:	total: 4s	remaining: 255ms
# 91:	total: 4s	remaining: 348ms
# 87:	total: 4.03s	remaining: 549ms
# 87:	total: 4.01s	remaining: 547ms
# 95:	total: 4.02s	remaining: 168ms
# 88:	total: 4.01s	remaining: 496ms
# 86:	total: 4.03s	remaining: 602ms
# 89:	total: 4.03s	remaining: 448ms
# 92:	total: 4.04s	remaining: 304ms
# 88:	total: 4.04s	remaining: 499ms
# 88:	total: 4.07s	remaining: 503ms
# 89:	total: 4.04s	remaining: 449ms
# 94:	total: 4.07s	remaining: 214ms
# 90:	total: 4.07s	remaining: 402ms
# 93:	total: 4.07s	remaining: 260ms
# 89:	total: 4.07s	remaining: 452ms
# 89:	total: 4.1s	remaining: 456ms
# 87:	total: 4.08s	remaining: 556ms
# 90:	total: 4.07s	remaining: 403ms
# 96:	total: 4.09s	remaining: 127ms
# 91:	total: 4.1s	remaining: 356ms
# 91:	total: 4.11s	remaining: 357ms
# 88:	total: 4.12s	remaining: 509ms
# 92:	total: 4.12s	remaining: 310ms
# 94:	total: 4.12s	remaining: 217ms
# 90:	total: 4.12s	remaining: 408ms
# 90:	total: 4.16s	remaining: 411ms
# 97:	total: 4.14s	remaining: 84.6ms
# 95:	total: 4.16s	remaining: 173ms
# 93:	total: 4.15s	remaining: 265ms
# 92:	total: 4.14s	remaining: 312ms
# 98:	total: 4.17s	remaining: 42.2ms
# 95:	total: 4.17s	remaining: 174ms
# 94:	total: 4.18s	remaining: 220ms
# 96:	total: 4.2s	remaining: 130ms
# 93:	total: 4.18s	remaining: 267ms
# 89:	total: 4.2s	remaining: 466ms
# 91:	total: 4.2s	remaining: 365ms
# 91:	total: 4.23s	remaining: 368ms
# 99:	total: 4.21s	remaining: 0us
# 97:	total: 4.23s	remaining: 86.3ms
# 96:	total: 4.22s	remaining: 131ms
# 90:	total: 4.23s	remaining: 419ms
# 92:	total: 4.23s	remaining: 319ms
# 94:	total: 4.22s	remaining: 222ms
# 95:	total: 4.24s	remaining: 177ms
# 92:	total: 4.28s	remaining: 322ms
# 98:	total: 4.27s	remaining: 43.2ms
# 97:	total: 4.27s	remaining: 87.1ms
# 91:	total: 4.27s	remaining: 372ms
# 93:	total: 4.28s	remaining: 273ms
# 95:	total: 4.27s	remaining: 178ms
# 92:	total: 4.3s	remaining: 324ms
# 93:	total: 4.33s	remaining: 276ms
# 94:	total: 4.31s	remaining: 227ms
# 96:	total: 4.31s	remaining: 133ms
# 99:	total: 4.33s	remaining: 0us
# 98:	total: 4.33s	remaining: 43.7ms
# 96:	total: 4.31s	remaining: 133ms
# 95:	total: 4.33s	remaining: 180ms
# 96:	total: 4.35s	remaining: 135ms
# 93:	total: 4.36s	remaining: 279ms
# 94:	total: 4.39s	remaining: 231ms
# 97:	total: 4.37s	remaining: 89.3ms
# 97:	total: 4.4s	remaining: 89.8ms
# 99:	total: 4.41s	remaining: 0us
# 95:	total: 4.44s	remaining: 185ms
# 97:	total: 4.42s	remaining: 90.2ms
# 94:	total: 4.42s	remaining: 233ms
# 98:	total: 4.42s	remaining: 44.6ms
# 98:	total: 4.46s	remaining: 45.1ms
# 99:	total: 4.47s	remaining: 0us
# 98:	total: 4.49s	remaining: 45.4ms
# 96:	total: 4.52s	remaining: 140ms
# 95:	total: 4.49s	remaining: 187ms
# 99:	total: 4.51s	remaining: 0us
# 97:	total: 4.58s	remaining: 93.5ms
# 99:	total: 4.56s	remaining: 0us
# 96:	total: 4.57s	remaining: 141ms
# 97:	total: 4.63s	remaining: 94.4ms
# 98:	total: 4.67s	remaining: 47.2ms
# 98:	total: 4.68s	remaining: 47.3ms
# 99:	total: 4.74s	remaining: 0us
# 0:	total: 95.6ms	remaining: 9.46s
# 99:	total: 4.76s	remaining: 0us
# 1:	total: 156ms	remaining: 7.63s
# 2:	total: 228ms	remaining: 7.37s
# 0:	total: 95.1ms	remaining: 9.41s
# 3:	total: 283ms	remaining: 6.8s
# 1:	total: 171ms	remaining: 8.37s
# 0:	total: 85.1ms	remaining: 8.42s
# 4:	total: 369ms	remaining: 7s
# 2:	total: 237ms	remaining: 7.66s
# 5:	total: 398ms	remaining: 6.23s
# 3:	total: 270ms	remaining: 6.49s
# 1:	total: 162ms	remaining: 7.91s
# 4:	total: 315ms	remaining: 5.98s
# 0:	total: 48.3ms	remaining: 4.79s
# 2:	total: 236ms	remaining: 7.63s
# 6:	total: 480ms	remaining: 6.37s
# 0:	total: 107ms	remaining: 10.6s
# 0:	total: 70.3ms	remaining: 6.96s
# 5:	total: 382ms	remaining: 5.99s
# 1:	total: 90.4ms	remaining: 4.43s
# 7:	total: 536ms	remaining: 6.16s
# 1:	total: 175ms	remaining: 8.55s
# 1:	total: 143ms	remaining: 7.03s
# 2:	total: 133ms	remaining: 4.3s
# 3:	total: 321ms	remaining: 7.69s
# 6:	total: 429ms	remaining: 5.69s
# 8:	total: 569ms	remaining: 5.75s
# 0:	total: 99.5ms	remaining: 9.85s
# 2:	total: 192ms	remaining: 6.21s
# 3:	total: 183ms	remaining: 4.4s
# 0:	total: 72.7ms	remaining: 14.5s
# 2:	total: 245ms	remaining: 7.91s
# 9:	total: 621ms	remaining: 5.59s
# 1:	total: 138ms	remaining: 6.75s
# 7:	total: 502ms	remaining: 5.78s
# 3:	total: 249ms	remaining: 5.97s
# 4:	total: 427ms	remaining: 8.11s
# 3:	total: 296ms	remaining: 7.11s
# 10:	total: 681ms	remaining: 5.51s
# 4:	total: 255ms	remaining: 4.84s
# 8:	total: 552ms	remaining: 5.58s
# 1:	total: 161ms	remaining: 15.9s
# 2:	total: 214ms	remaining: 6.93s
# 4:	total: 338ms	remaining: 6.43s
# 11:	total: 716ms	remaining: 5.25s
# 4:	total: 306ms	remaining: 5.82s
# 5:	total: 482ms	remaining: 7.55s
# 9:	total: 594ms	remaining: 5.34s
# 3:	total: 241ms	remaining: 5.78s
# 5:	total: 309ms	remaining: 4.84s
# 5:	total: 365ms	remaining: 5.72s
# 2:	total: 206ms	remaining: 13.5s
# 6:	total: 519ms	remaining: 6.89s
# 10:	total: 627ms	remaining: 5.07s
# 12:	total: 769ms	remaining: 5.14s
# 4:	total: 280ms	remaining: 5.33s
# 5:	total: 369ms	remaining: 5.79s
# 6:	total: 409ms	remaining: 5.43s
# 11:	total: 654ms	remaining: 4.79s
# 6:	total: 367ms	remaining: 4.88s
# 3:	total: 255ms	remaining: 12.5s
# 7:	total: 557ms	remaining: 6.4s
# 13:	total: 814ms	remaining: 5s
# 7:	total: 438ms	remaining: 5.04s
# 5:	total: 331ms	remaining: 5.19s
# 8:	total: 587ms	remaining: 5.93s
# 6:	total: 416ms	remaining: 5.53s
# 12:	total: 700ms	remaining: 4.68s
# 7:	total: 420ms	remaining: 4.83s
# 4:	total: 313ms	remaining: 12.2s
# 14:	total: 852ms	remaining: 4.83s
# 6:	total: 365ms	remaining: 4.85s
# 8:	total: 446ms	remaining: 4.5s
# 13:	total: 756ms	remaining: 4.64s
# 7:	total: 405ms	remaining: 4.66s
# 8:	total: 521ms	remaining: 5.27s
# 9:	total: 657ms	remaining: 5.91s
# 7:	total: 485ms	remaining: 5.58s
# 15:	total: 902ms	remaining: 4.74s
# 5:	total: 372ms	remaining: 12s
# 9:	total: 492ms	remaining: 4.43s
# 14:	total: 794ms	remaining: 4.5s
# 9:	total: 554ms	remaining: 4.99s
# 8:	total: 444ms	remaining: 4.48s
# 16:	total: 945ms	remaining: 4.61s
# 10:	total: 716ms	remaining: 5.79s
# 15:	total: 830ms	remaining: 4.36s
# 10:	total: 587ms	remaining: 4.75s
# 8:	total: 549ms	remaining: 5.55s
# 6:	total: 437ms	remaining: 12.1s
# 11:	total: 739ms	remaining: 5.42s
# 10:	total: 564ms	remaining: 4.56s
# 9:	total: 504ms	remaining: 4.54s
# 16:	total: 867ms	remaining: 4.23s
# 17:	total: 1.01s	remaining: 4.59s
# 7:	total: 477ms	remaining: 11.4s
# 9:	total: 603ms	remaining: 5.43s
# 12:	total: 777ms	remaining: 5.2s
# 10:	total: 530ms	remaining: 4.29s
# 11:	total: 652ms	remaining: 4.78s
# 17:	total: 903ms	remaining: 4.11s
# 18:	total: 1.04s	remaining: 4.44s
# 8:	total: 519ms	remaining: 11s
# 11:	total: 568ms	remaining: 4.16s
# 13:	total: 817ms	remaining: 5.02s
# 10:	total: 652ms	remaining: 5.28s
# 11:	total: 648ms	remaining: 4.75s
# 18:	total: 946ms	remaining: 4.03s
# 12:	total: 716ms	remaining: 4.79s
# 19:	total: 1.1s	remaining: 4.39s
# 11:	total: 688ms	remaining: 5.05s
# 14:	total: 861ms	remaining: 4.88s
# 19:	total: 978ms	remaining: 3.91s
# 9:	total: 576ms	remaining: 10.9s
# 12:	total: 627ms	remaining: 4.2s
# 12:	total: 716ms	remaining: 4.79s
# 20:	total: 1.14s	remaining: 4.28s
# 12:	total: 713ms	remaining: 4.77s
# 13:	total: 768ms	remaining: 4.71s
# 10:	total: 606ms	remaining: 10.4s
# 20:	total: 1.02s	remaining: 3.82s
# 13:	total: 660ms	remaining: 4.05s
# 15:	total: 929ms	remaining: 4.88s
# 13:	total: 758ms	remaining: 4.65s
# 14:	total: 781ms	remaining: 4.42s
# 21:	total: 1.06s	remaining: 3.75s
# 14:	total: 821ms	remaining: 4.65s
# 21:	total: 1.2s	remaining: 4.25s
# 11:	total: 663ms	remaining: 10.4s
# 16:	total: 979ms	remaining: 4.78s
# 14:	total: 727ms	remaining: 4.12s
# 13:	total: 802ms	remaining: 4.93s
# 22:	total: 1.09s	remaining: 3.67s
# 15:	total: 862ms	remaining: 4.52s
# 22:	total: 1.24s	remaining: 4.16s
# 15:	total: 829ms	remaining: 4.35s
# 15:	total: 766ms	remaining: 4.02s
# 17:	total: 1.03s	remaining: 4.71s
# 12:	total: 737ms	remaining: 10.6s
# 16:	total: 900ms	remaining: 4.39s
# 16:	total: 864ms	remaining: 4.22s
# 23:	total: 1.14s	remaining: 3.61s
# 14:	total: 854ms	remaining: 4.84s
# 23:	total: 1.29s	remaining: 4.1s
# 17:	total: 932ms	remaining: 4.25s
# 18:	total: 1.07s	remaining: 4.56s
# 17:	total: 908ms	remaining: 4.14s
# 24:	total: 1.19s	remaining: 3.56s
# 13:	total: 786ms	remaining: 10.4s
# 16:	total: 831ms	remaining: 4.06s
# 24:	total: 1.33s	remaining: 3.98s
# 15:	total: 904ms	remaining: 4.74s
# 19:	total: 1.1s	remaining: 4.41s
# 18:	total: 972ms	remaining: 4.14s
# 14:	total: 821ms	remaining: 10.1s
# 18:	total: 951ms	remaining: 4.05s
# 17:	total: 872ms	remaining: 3.97s
# 25:	total: 1.23s	remaining: 3.51s
# 25:	total: 1.38s	remaining: 3.92s
# 20:	total: 1.14s	remaining: 4.3s
# 19:	total: 1.01s	remaining: 4.05s
# 18:	total: 898ms	remaining: 3.83s
# 15:	total: 856ms	remaining: 9.84s
# 19:	total: 986ms	remaining: 3.94s
# 16:	total: 976ms	remaining: 4.77s
# 21:	total: 1.18s	remaining: 4.18s
# 26:	total: 1.42s	remaining: 3.84s
# 26:	total: 1.28s	remaining: 3.47s
# 19:	total: 940ms	remaining: 3.76s
# 20:	total: 1.03s	remaining: 3.87s
# 16:	total: 904ms	remaining: 9.73s
# 20:	total: 1.07s	remaining: 4.01s
# 27:	total: 1.45s	remaining: 3.72s
# 17:	total: 1.02s	remaining: 4.65s
# 27:	total: 1.31s	remaining: 3.38s
# 21:	total: 1.09s	remaining: 3.86s
# 22:	total: 1.23s	remaining: 4.13s
# 18:	total: 1.05s	remaining: 4.48s
# 20:	total: 988ms	remaining: 3.72s
# 28:	total: 1.35s	remaining: 3.31s
# 28:	total: 1.49s	remaining: 3.64s
# 17:	total: 956ms	remaining: 9.67s
# 21:	total: 1.08s	remaining: 3.84s
# 22:	total: 1.13s	remaining: 3.78s
# 19:	total: 1.08s	remaining: 4.33s
# 21:	total: 1.02s	remaining: 3.61s
# 23:	total: 1.28s	remaining: 4.05s
# 29:	total: 1.39s	remaining: 3.25s
# 29:	total: 1.53s	remaining: 3.57s
# 22:	total: 1.13s	remaining: 3.77s
# 20:	total: 1.12s	remaining: 4.21s
# 23:	total: 1.17s	remaining: 3.71s
# 22:	total: 1.05s	remaining: 3.52s
# 18:	total: 1.01s	remaining: 9.63s
# 30:	total: 1.43s	remaining: 3.19s
# 21:	total: 1.15s	remaining: 4.07s
# 23:	total: 1.16s	remaining: 3.69s
# 24:	total: 1.34s	remaining: 4.01s
# 30:	total: 1.57s	remaining: 3.5s
# 23:	total: 1.09s	remaining: 3.44s
# 24:	total: 1.23s	remaining: 3.69s
# 19:	total: 1.07s	remaining: 9.62s
# 31:	total: 1.6s	remaining: 3.4s
# 24:	total: 1.19s	remaining: 3.58s
# 25:	total: 1.37s	remaining: 3.89s
# 22:	total: 1.2s	remaining: 4.01s
# 31:	total: 1.49s	remaining: 3.17s
# 25:	total: 1.23s	remaining: 3.49s
# 24:	total: 1.15s	remaining: 3.45s
# 32:	total: 1.64s	remaining: 3.33s
# 20:	total: 1.11s	remaining: 9.46s
# 25:	total: 1.28s	remaining: 3.65s
# 26:	total: 1.42s	remaining: 3.84s
# 23:	total: 1.23s	remaining: 3.91s
# 26:	total: 1.26s	remaining: 3.4s
# 32:	total: 1.53s	remaining: 3.12s
# 33:	total: 1.67s	remaining: 3.24s
# 21:	total: 1.14s	remaining: 9.23s
# 25:	total: 1.2s	remaining: 3.4s
# 27:	total: 1.46s	remaining: 3.75s
# 26:	total: 1.33s	remaining: 3.6s
# 27:	total: 1.3s	remaining: 3.35s
# 22:	total: 1.18s	remaining: 9.09s
# 26:	total: 1.22s	remaining: 3.31s
# 34:	total: 1.72s	remaining: 3.19s
# 33:	total: 1.58s	remaining: 3.08s
# 24:	total: 1.3s	remaining: 3.9s
# 28:	total: 1.5s	remaining: 3.67s
# 35:	total: 1.74s	remaining: 3.09s
# 28:	total: 1.33s	remaining: 3.27s
# 27:	total: 1.38s	remaining: 3.54s
# 27:	total: 1.26s	remaining: 3.23s
# 23:	total: 1.22s	remaining: 8.93s
# 34:	total: 1.63s	remaining: 3.02s
# 25:	total: 1.34s	remaining: 3.82s
# 29:	total: 1.53s	remaining: 3.57s
# 29:	total: 1.37s	remaining: 3.19s
# 36:	total: 1.78s	remaining: 3.04s
# 24:	total: 1.26s	remaining: 8.82s
# 28:	total: 1.44s	remaining: 3.53s
# 35:	total: 1.68s	remaining: 2.99s
# 28:	total: 1.33s	remaining: 3.26s
# 37:	total: 1.82s	remaining: 2.98s
# 30:	total: 1.42s	remaining: 3.15s
# 26:	total: 1.42s	remaining: 3.83s
# 30:	total: 1.6s	remaining: 3.57s
# 29:	total: 1.47s	remaining: 3.44s
# 29:	total: 1.36s	remaining: 3.18s
# 31:	total: 1.45s	remaining: 3.07s
# 38:	total: 1.87s	remaining: 2.92s
# 25:	total: 1.33s	remaining: 8.92s
# 27:	total: 1.45s	remaining: 3.72s
# 36:	total: 1.74s	remaining: 2.96s
# 31:	total: 1.64s	remaining: 3.49s
# 30:	total: 1.52s	remaining: 3.37s
# 30:	total: 1.4s	remaining: 3.11s
# 39:	total: 1.89s	remaining: 2.84s
# 28:	total: 1.49s	remaining: 3.65s
# 32:	total: 1.51s	remaining: 3.06s
# 31:	total: 1.43s	remaining: 3.03s
# 32:	total: 1.68s	remaining: 3.42s
# 26:	total: 1.39s	remaining: 8.9s
# 31:	total: 1.55s	remaining: 3.3s
# 37:	total: 1.79s	remaining: 2.92s
# 40:	total: 1.93s	remaining: 2.78s
# 29:	total: 1.52s	remaining: 3.54s
# 33:	total: 1.54s	remaining: 2.99s
# 33:	total: 1.71s	remaining: 3.32s
# 32:	total: 1.48s	remaining: 3s
# 27:	total: 1.45s	remaining: 8.93s
# 38:	total: 1.85s	remaining: 2.9s
# 32:	total: 1.62s	remaining: 3.29s
# 34:	total: 1.58s	remaining: 2.94s
# 30:	total: 1.57s	remaining: 3.5s
# 34:	total: 1.76s	remaining: 3.27s
# 41:	total: 2s	remaining: 2.77s
# 33:	total: 1.52s	remaining: 2.96s
# 35:	total: 1.61s	remaining: 2.87s
# 28:	total: 1.49s	remaining: 8.77s
# 39:	total: 1.9s	remaining: 2.85s
# 35:	total: 1.8s	remaining: 3.2s
# 33:	total: 1.67s	remaining: 3.25s
# 29:	total: 1.52s	remaining: 8.6s
# 31:	total: 1.63s	remaining: 3.46s
# 34:	total: 1.56s	remaining: 2.9s
# 42:	total: 2.06s	remaining: 2.73s
# 36:	total: 1.67s	remaining: 2.84s
# 40:	total: 1.94s	remaining: 2.79s
# 34:	total: 1.71s	remaining: 3.17s
# 30:	total: 1.56s	remaining: 8.5s
# 36:	total: 1.85s	remaining: 3.16s
# 43:	total: 2.1s	remaining: 2.67s
# 32:	total: 1.67s	remaining: 3.4s
# 35:	total: 1.61s	remaining: 2.86s
# 35:	total: 1.74s	remaining: 3.1s
# 41:	total: 1.99s	remaining: 2.75s
# 33:	total: 1.7s	remaining: 3.31s
# 44:	total: 2.13s	remaining: 2.6s
# 31:	total: 1.6s	remaining: 8.39s
# 37:	total: 1.73s	remaining: 2.81s
# 37:	total: 1.9s	remaining: 3.1s
# 36:	total: 1.77s	remaining: 3.02s
# 36:	total: 1.67s	remaining: 2.84s
# 38:	total: 1.75s	remaining: 2.74s
# 45:	total: 2.16s	remaining: 2.54s
# 42:	total: 2.04s	remaining: 2.7s
# 32:	total: 1.64s	remaining: 8.3s
# 38:	total: 1.94s	remaining: 3.03s
# 34:	total: 1.75s	remaining: 3.25s
# 37:	total: 1.82s	remaining: 2.96s
# 39:	total: 1.78s	remaining: 2.67s
# 46:	total: 2.2s	remaining: 2.48s
# 37:	total: 1.72s	remaining: 2.8s
# 39:	total: 1.97s	remaining: 2.95s
# 35:	total: 1.78s	remaining: 3.17s
# 33:	total: 1.68s	remaining: 8.21s
# 43:	total: 2.08s	remaining: 2.65s
# 40:	total: 1.81s	remaining: 2.6s
# 38:	total: 1.74s	remaining: 2.71s
# 40:	total: 2s	remaining: 2.88s
# 36:	total: 1.82s	remaining: 3.11s
# 38:	total: 1.88s	remaining: 2.94s
# 47:	total: 2.25s	remaining: 2.44s
# 39:	total: 1.77s	remaining: 2.66s
# 41:	total: 1.86s	remaining: 2.57s
# 34:	total: 1.74s	remaining: 8.21s
# 37:	total: 1.85s	remaining: 3.02s
# 44:	total: 2.15s	remaining: 2.62s
# 48:	total: 2.28s	remaining: 2.38s
# 41:	total: 2.05s	remaining: 2.83s
# 39:	total: 1.93s	remaining: 2.9s
# 40:	total: 1.82s	remaining: 2.62s
# 45:	total: 2.18s	remaining: 2.56s
# 49:	total: 2.31s	remaining: 2.31s
# 42:	total: 1.91s	remaining: 2.53s
# 35:	total: 1.79s	remaining: 8.14s
# 38:	total: 1.9s	remaining: 2.97s
# 42:	total: 2.08s	remaining: 2.76s
# 40:	total: 1.97s	remaining: 2.83s
# 46:	total: 2.2s	remaining: 2.48s
# 50:	total: 2.35s	remaining: 2.26s
# 41:	total: 1.86s	remaining: 2.57s
# 39:	total: 1.93s	remaining: 2.9s
# 43:	total: 2.12s	remaining: 2.7s
# 47:	total: 2.23s	remaining: 2.41s
# 41:	total: 2s	remaining: 2.77s
# 43:	total: 1.97s	remaining: 2.51s
# 51:	total: 2.38s	remaining: 2.2s
# 36:	total: 1.85s	remaining: 8.16s
# 42:	total: 1.89s	remaining: 2.51s
# 40:	total: 1.97s	remaining: 2.83s
# 44:	total: 2.15s	remaining: 2.63s
# 48:	total: 2.28s	remaining: 2.38s
# 44:	total: 2.01s	remaining: 2.46s
# 52:	total: 2.42s	remaining: 2.15s
# 37:	total: 1.89s	remaining: 8.05s
# 43:	total: 1.93s	remaining: 2.46s
# 42:	total: 2.06s	remaining: 2.73s
# 45:	total: 2.21s	remaining: 2.59s
# 49:	total: 2.31s	remaining: 2.31s
# 41:	total: 2.02s	remaining: 2.79s
# 44:	total: 1.96s	remaining: 2.4s
# 45:	total: 2.06s	remaining: 2.42s
# 38:	total: 1.94s	remaining: 8.01s
# 53:	total: 2.47s	remaining: 2.11s
# 45:	total: 1.99s	remaining: 2.34s
# 50:	total: 2.35s	remaining: 2.26s
# 42:	total: 2.07s	remaining: 2.74s
# 43:	total: 2.13s	remaining: 2.71s
# 46:	total: 2.1s	remaining: 2.36s
# 39:	total: 1.97s	remaining: 7.9s
# 54:	total: 2.51s	remaining: 2.05s
# 46:	total: 2.27s	remaining: 2.56s
# 46:	total: 2.03s	remaining: 2.29s
# 40:	total: 2s	remaining: 7.76s
# 43:	total: 2.11s	remaining: 2.68s
# 55:	total: 2.54s	remaining: 1.99s
# 47:	total: 2.13s	remaining: 2.31s
# 51:	total: 2.42s	remaining: 2.23s
# 44:	total: 2.19s	remaining: 2.67s
# 47:	total: 2.07s	remaining: 2.25s
# 47:	total: 2.33s	remaining: 2.52s
# 48:	total: 2.16s	remaining: 2.25s
# 56:	total: 2.57s	remaining: 1.94s
# 44:	total: 2.15s	remaining: 2.63s
# 41:	total: 2.06s	remaining: 7.75s
# 48:	total: 2.36s	remaining: 2.45s
# 52:	total: 2.46s	remaining: 2.18s
# 48:	total: 2.11s	remaining: 2.2s
# 57:	total: 2.6s	remaining: 1.89s
# 49:	total: 2.2s	remaining: 2.2s
# 45:	total: 2.2s	remaining: 2.58s
# 42:	total: 2.1s	remaining: 7.65s
# 45:	total: 2.26s	remaining: 2.65s
# 58:	total: 2.63s	remaining: 1.83s
# 53:	total: 2.5s	remaining: 2.13s
# 49:	total: 2.4s	remaining: 2.4s
# 50:	total: 2.24s	remaining: 2.15s
# 49:	total: 2.16s	remaining: 2.16s
# 43:	total: 2.13s	remaining: 7.56s
# 59:	total: 2.66s	remaining: 1.78s
# 46:	total: 2.3s	remaining: 2.59s
# 50:	total: 2.44s	remaining: 2.34s
# 46:	total: 2.25s	remaining: 2.54s
# 51:	total: 2.27s	remaining: 2.1s
# 50:	total: 2.2s	remaining: 2.11s
# 54:	total: 2.56s	remaining: 2.09s
# 44:	total: 2.16s	remaining: 7.43s
# 60:	total: 2.7s	remaining: 1.72s
# 51:	total: 2.47s	remaining: 2.28s
# 52:	total: 2.31s	remaining: 2.05s
# 47:	total: 2.3s	remaining: 2.5s
# 61:	total: 2.73s	remaining: 1.67s
# 55:	total: 2.6s	remaining: 2.04s
# 47:	total: 2.36s	remaining: 2.56s
# 51:	total: 2.25s	remaining: 2.07s
# 45:	total: 2.22s	remaining: 7.44s
# 62:	total: 2.76s	remaining: 1.62s
# 53:	total: 2.35s	remaining: 2s
# 56:	total: 2.63s	remaining: 1.98s
# 48:	total: 2.34s	remaining: 2.44s
# 52:	total: 2.28s	remaining: 2.02s
# 52:	total: 2.54s	remaining: 2.25s
# 54:	total: 2.39s	remaining: 1.95s
# 63:	total: 2.8s	remaining: 1.57s
# 48:	total: 2.43s	remaining: 2.53s
# 53:	total: 2.57s	remaining: 2.19s
# 46:	total: 2.27s	remaining: 7.41s
# 57:	total: 2.67s	remaining: 1.94s
# 53:	total: 2.32s	remaining: 1.98s
# 49:	total: 2.4s	remaining: 2.4s
# 54:	total: 2.6s	remaining: 2.12s
# 58:	total: 2.7s	remaining: 1.88s
# 64:	total: 2.85s	remaining: 1.53s
# 49:	total: 2.48s	remaining: 2.48s
# 55:	total: 2.44s	remaining: 1.92s
# 50:	total: 2.43s	remaining: 2.33s
# 54:	total: 2.37s	remaining: 1.94s
# 55:	total: 2.62s	remaining: 2.06s
# 55:	total: 2.4s	remaining: 1.88s
# 56:	total: 2.64s	remaining: 2s
# 56:	total: 2.47s	remaining: 1.86s
# 50:	total: 2.52s	remaining: 2.42s
# 47:	total: 2.35s	remaining: 7.43s
# 59:	total: 2.74s	remaining: 1.83s
# 51:	total: 2.46s	remaining: 2.27s
# 65:	total: 2.89s	remaining: 1.49s
# 57:	total: 2.67s	remaining: 1.94s
# 57:	total: 2.51s	remaining: 1.81s
# 66:	total: 2.93s	remaining: 1.44s
# 56:	total: 2.44s	remaining: 1.84s
# 48:	total: 2.39s	remaining: 7.37s
# 51:	total: 2.56s	remaining: 2.37s
# 60:	total: 2.79s	remaining: 1.78s
# 52:	total: 2.51s	remaining: 2.23s
# 58:	total: 2.7s	remaining: 1.88s
# 67:	total: 2.95s	remaining: 1.39s
# 58:	total: 2.54s	remaining: 1.77s
# 57:	total: 2.47s	remaining: 1.79s
# 53:	total: 2.55s	remaining: 2.17s
# 49:	total: 2.44s	remaining: 7.33s
# 68:	total: 2.98s	remaining: 1.34s
# 59:	total: 2.75s	remaining: 1.83s
# 52:	total: 2.63s	remaining: 2.33s
# 61:	total: 2.85s	remaining: 1.75s
# 58:	total: 2.51s	remaining: 1.75s
# 59:	total: 2.59s	remaining: 1.73s
# 54:	total: 2.6s	remaining: 2.12s
# 69:	total: 3.03s	remaining: 1.3s
# 62:	total: 2.89s	remaining: 1.7s
# 60:	total: 2.79s	remaining: 1.78s
# 50:	total: 2.51s	remaining: 7.33s
# 53:	total: 2.68s	remaining: 2.29s
# 61:	total: 2.81s	remaining: 1.73s
# 63:	total: 2.92s	remaining: 1.64s
# 60:	total: 2.65s	remaining: 1.69s
# 59:	total: 2.58s	remaining: 1.72s
# 55:	total: 2.64s	remaining: 2.07s
# 70:	total: 3.07s	remaining: 1.25s
# 54:	total: 2.71s	remaining: 2.22s
# 64:	total: 2.94s	remaining: 1.58s
# 51:	total: 2.56s	remaining: 7.28s
# 62:	total: 2.86s	remaining: 1.68s
# 61:	total: 2.69s	remaining: 1.65s
# 60:	total: 2.62s	remaining: 1.68s
# 55:	total: 2.75s	remaining: 2.16s
# 56:	total: 2.69s	remaining: 2.03s
# 65:	total: 2.98s	remaining: 1.54s
# 71:	total: 3.13s	remaining: 1.22s
# 52:	total: 2.6s	remaining: 7.2s
# 63:	total: 2.89s	remaining: 1.63s
# 61:	total: 2.65s	remaining: 1.62s
# 62:	total: 2.73s	remaining: 1.6s
# 57:	total: 2.72s	remaining: 1.97s
# 56:	total: 2.8s	remaining: 2.11s
# 53:	total: 2.63s	remaining: 7.11s
# 72:	total: 3.17s	remaining: 1.17s
# 64:	total: 2.93s	remaining: 1.58s
# 58:	total: 2.75s	remaining: 1.91s
# 62:	total: 2.69s	remaining: 1.58s
# 54:	total: 2.65s	remaining: 7s
# 63:	total: 2.78s	remaining: 1.57s
# 66:	total: 3.06s	remaining: 1.51s
# 63:	total: 2.72s	remaining: 1.53s
# 73:	total: 3.21s	remaining: 1.13s
# 55:	total: 2.68s	remaining: 6.89s
# 65:	total: 2.98s	remaining: 1.53s
# 57:	total: 2.85s	remaining: 2.07s
# 59:	total: 2.8s	remaining: 1.87s
# 74:	total: 3.25s	remaining: 1.08s
# 64:	total: 2.76s	remaining: 1.49s
# 67:	total: 3.11s	remaining: 1.46s
# 58:	total: 2.89s	remaining: 2s
# 66:	total: 3.02s	remaining: 1.49s
# 65:	total: 2.78s	remaining: 1.43s
# 64:	total: 2.86s	remaining: 1.54s
# 75:	total: 3.27s	remaining: 1.03s
# 67:	total: 3.04s	remaining: 1.43s
# 56:	total: 2.75s	remaining: 6.89s
# 68:	total: 3.15s	remaining: 1.42s
# 60:	total: 2.87s	remaining: 1.83s
# 59:	total: 2.93s	remaining: 1.96s
# 68:	total: 3.07s	remaining: 1.38s
# 76:	total: 3.31s	remaining: 989ms
# 66:	total: 2.83s	remaining: 1.39s
# 57:	total: 2.78s	remaining: 6.81s
# 65:	total: 2.92s	remaining: 1.5s
# 69:	total: 3.2s	remaining: 1.37s
# 61:	total: 2.91s	remaining: 1.78s
# 69:	total: 3.1s	remaining: 1.33s
# 60:	total: 2.98s	remaining: 1.9s
# 77:	total: 3.35s	remaining: 946ms
# 66:	total: 2.94s	remaining: 1.45s
# 58:	total: 2.83s	remaining: 6.76s
# 61:	total: 3.01s	remaining: 1.85s
# 62:	total: 2.95s	remaining: 1.73s
# 70:	total: 3.14s	remaining: 1.28s
# 70:	total: 3.24s	remaining: 1.32s
# 67:	total: 2.98s	remaining: 1.4s
# 78:	total: 3.39s	remaining: 902ms
# 59:	total: 2.87s	remaining: 6.69s
# 67:	total: 2.92s	remaining: 1.37s
# 79:	total: 3.42s	remaining: 855ms
# 71:	total: 3.28s	remaining: 1.28s
# 68:	total: 2.94s	remaining: 1.32s
# 71:	total: 3.19s	remaining: 1.24s
# 68:	total: 3.02s	remaining: 1.36s
# 80:	total: 3.44s	remaining: 808ms
# 60:	total: 2.91s	remaining: 6.63s
# 63:	total: 3.02s	remaining: 1.7s
# 72:	total: 3.31s	remaining: 1.23s
# 62:	total: 3.1s	remaining: 1.82s
# 72:	total: 3.23s	remaining: 1.19s
# 69:	total: 3.06s	remaining: 1.31s
# 69:	total: 2.99s	remaining: 1.28s
# 73:	total: 3.34s	remaining: 1.17s
# 64:	total: 3.06s	remaining: 1.65s
# 81:	total: 3.49s	remaining: 767ms
# 61:	total: 2.97s	remaining: 6.61s
# 63:	total: 3.15s	remaining: 1.77s
# 70:	total: 3.11s	remaining: 1.27s
# 65:	total: 3.1s	remaining: 1.59s
# 73:	total: 3.29s	remaining: 1.16s
# 70:	total: 3.05s	remaining: 1.24s
# 74:	total: 3.39s	remaining: 1.13s
# 82:	total: 3.54s	remaining: 724ms
# 62:	total: 3s	remaining: 6.52s
# 64:	total: 3.17s	remaining: 1.71s
# 74:	total: 3.32s	remaining: 1.11s
# 66:	total: 3.14s	remaining: 1.54s
# 83:	total: 3.57s	remaining: 680ms
# 75:	total: 3.43s	remaining: 1.08s
# 63:	total: 3.04s	remaining: 6.45s
# 71:	total: 3.16s	remaining: 1.23s
# 65:	total: 3.21s	remaining: 1.65s
# 71:	total: 3.09s	remaining: 1.2s
# 67:	total: 3.17s	remaining: 1.49s
# 75:	total: 3.38s	remaining: 1.07s
# 84:	total: 3.62s	remaining: 638ms
# 72:	total: 3.13s	remaining: 1.16s
# 72:	total: 3.21s	remaining: 1.19s
# 66:	total: 3.26s	remaining: 1.6s
# 68:	total: 3.2s	remaining: 1.44s
# 64:	total: 3.1s	remaining: 6.43s
# 76:	total: 3.49s	remaining: 1.04s
# 85:	total: 3.64s	remaining: 592ms
# 76:	total: 3.41s	remaining: 1.02s
# 73:	total: 3.17s	remaining: 1.11s
# 65:	total: 3.13s	remaining: 6.36s
# 77:	total: 3.53s	remaining: 995ms
# 69:	total: 3.25s	remaining: 1.39s
# 73:	total: 3.27s	remaining: 1.15s
# 67:	total: 3.32s	remaining: 1.56s
# 74:	total: 3.2s	remaining: 1.07s
# 86:	total: 3.69s	remaining: 552ms
# 77:	total: 3.46s	remaining: 977ms
# 66:	total: 3.17s	remaining: 6.29s
# 87:	total: 3.72s	remaining: 508ms
# 70:	total: 3.29s	remaining: 1.35s
# 74:	total: 3.31s	remaining: 1.1s
# 75:	total: 3.24s	remaining: 1.02s
# 78:	total: 3.49s	remaining: 928ms
# 78:	total: 3.59s	remaining: 954ms
# 68:	total: 3.36s	remaining: 1.51s
# 75:	total: 3.33s	remaining: 1.05s
# 71:	total: 3.33s	remaining: 1.29s
# 69:	total: 3.4s	remaining: 1.46s
# 76:	total: 3.28s	remaining: 980ms
# 79:	total: 3.63s	remaining: 908ms
# 76:	total: 3.36s	remaining: 1s
# 67:	total: 3.24s	remaining: 6.29s
# 88:	total: 3.78s	remaining: 468ms
# 70:	total: 3.42s	remaining: 1.4s
# 72:	total: 3.36s	remaining: 1.24s
# 79:	total: 3.56s	remaining: 889ms
# 77:	total: 3.32s	remaining: 936ms
# 68:	total: 3.27s	remaining: 6.21s
# 80:	total: 3.67s	remaining: 860ms
# 89:	total: 3.83s	remaining: 426ms
# 73:	total: 3.41s	remaining: 1.2s
# 80:	total: 3.6s	remaining: 844ms
# 81:	total: 3.7s	remaining: 812ms
# 78:	total: 3.36s	remaining: 892ms
# ...
# 677:	total: 41.3s	remaining: 19.6s
# 304:	total: 15.5s	remaining: 35.3s
# 237:	total: 12.5s	remaining: 39.9s
# 175:	total: 9.6s	remaining: 45s
# 191:	total: 10.3s	remaining: 43.2s
# 213:	total: 11s	remaining: 40.5s
# 287:	total: 14.7s	remaining: 36.3s
# 174:	total: 9.2s	remaining: 43.4s
# 238:	total: 12.5s	remaining: 39.8s
# 678:	total: 41.3s	remaining: 19.5s
# 176:	total: 9.67s	remaining: 45s
# 175:	total: 9.24s	remaining: 43.3s
# 214:	total: 11.1s	remaining: 40.6s
# 305:	total: 15.6s	remaining: 35.3s
# 288:	total: 14.8s	remaining: 36.3s
# 192:	total: 10.4s	remaining: 43.3s
# 239:	total: 12.6s	remaining: 39.8s
# 177:	total: 9.71s	remaining: 44.8s
# 176:	total: 9.28s	remaining: 43.2s
# 178:	total: 9.74s	remaining: 44.7s
# 289:	total: 14.8s	remaining: 36.3s
# 193:	total: 10.4s	remaining: 43.2s
# 215:	total: 11.2s	remaining: 40.6s
# 306:	total: 15.6s	remaining: 35.3s
# 679:	total: 41.5s	remaining: 19.5s
# 240:	total: 12.6s	remaining: 39.8s
# 194:	total: 10.4s	remaining: 43.1s
# 241:	total: 12.7s	remaining: 39.7s
# 177:	total: 9.37s	remaining: 43.3s
# 680:	total: 41.5s	remaining: 19.4s
# 216:	total: 11.2s	remaining: 40.6s
# 179:	total: 9.82s	remaining: 44.7s
# 290:	total: 14.9s	remaining: 36.3s
# 178:	total: 9.4s	remaining: 43.1s
# 307:	total: 15.7s	remaining: 35.3s
# 195:	total: 10.5s	remaining: 43.1s
# 242:	total: 12.7s	remaining: 39.6s
# 180:	total: 9.87s	remaining: 44.7s
# 308:	total: 15.8s	remaining: 35.2s
# 681:	total: 41.6s	remaining: 19.4s
# 196:	total: 10.5s	remaining: 42.9s
# 243:	total: 12.7s	remaining: 39.5s
# 179:	total: 9.45s	remaining: 43s
# 217:	total: 11.3s	remaining: 40.6s
# 291:	total: 15s	remaining: 36.3s
# 180:	total: 9.48s	remaining: 42.9s
# 244:	total: 12.8s	remaining: 39.4s
# 197:	total: 10.6s	remaining: 42.8s
# 682:	total: 41.6s	remaining: 19.3s
# 181:	total: 9.93s	remaining: 44.6s
# 181:	total: 9.5s	remaining: 42.7s
# 292:	total: 15s	remaining: 36.2s
# 182:	total: 9.96s	remaining: 44.5s
# 218:	total: 11.4s	remaining: 40.6s
# 309:	total: 15.9s	remaining: 35.3s
# 293:	total: 15.1s	remaining: 36.2s
# 683:	total: 41.7s	remaining: 19.3s
# 219:	total: 11.4s	remaining: 40.5s
# 198:	total: 10.7s	remaining: 42.9s
# 245:	total: 12.9s	remaining: 39.4s
# 182:	total: 9.58s	remaining: 42.8s
# 183:	total: 10s	remaining: 44.4s
# 246:	total: 12.9s	remaining: 39.3s
# 220:	total: 11.5s	remaining: 40.4s
# 294:	total: 15.1s	remaining: 36.1s
# 199:	total: 10.7s	remaining: 42.8s
# 310:	total: 15.9s	remaining: 35.3s
# 183:	total: 9.64s	remaining: 42.8s
# 684:	total: 41.8s	remaining: 19.2s
# 184:	total: 10.1s	remaining: 44.4s
# 200:	total: 10.7s	remaining: 42.7s
# 295:	total: 15.2s	remaining: 36s
# 221:	total: 11.5s	remaining: 40.3s
# 247:	total: 12.9s	remaining: 39.2s
# 311:	total: 16s	remaining: 35.3s
# 685:	total: 41.8s	remaining: 19.1s
# 184:	total: 9.69s	remaining: 42.7s
# 222:	total: 11.5s	remaining: 40.2s
# 185:	total: 10.1s	remaining: 44.3s
# 201:	total: 10.8s	remaining: 42.6s
# 296:	total: 15.2s	remaining: 36s
# 686:	total: 41.8s	remaining: 19.1s
# 185:	total: 9.72s	remaining: 42.5s
# 248:	total: 13s	remaining: 39.2s
# 312:	total: 16.1s	remaining: 35.2s
# 186:	total: 10.2s	remaining: 44.2s
# 223:	total: 11.6s	remaining: 40.2s
# 202:	total: 10.8s	remaining: 42.6s
# 297:	total: 15.3s	remaining: 36s
# 249:	total: 13.1s	remaining: 39.2s
# 186:	total: 9.77s	remaining: 42.5s
# 313:	total: 16.1s	remaining: 35.2s
# 187:	total: 10.2s	remaining: 44.1s
# 224:	total: 11.6s	remaining: 40.1s
# 687:	total: 41.9s	remaining: 19s
# 250:	total: 13.1s	remaining: 39.1s
# 298:	total: 15.3s	remaining: 35.9s
# 203:	total: 10.9s	remaining: 42.5s
# 314:	total: 16.1s	remaining: 35.1s
# 688:	total: 41.9s	remaining: 18.9s
# 225:	total: 11.7s	remaining: 40s
# 188:	total: 10.3s	remaining: 44s
# 204:	total: 10.9s	remaining: 42.4s
# 187:	total: 9.84s	remaining: 42.5s
# 299:	total: 15.4s	remaining: 35.8s
# 226:	total: 11.7s	remaining: 39.9s
# 251:	total: 13.2s	remaining: 39s
# 315:	total: 16.2s	remaining: 35s
# 189:	total: 10.3s	remaining: 43.9s
# 689:	total: 42s	remaining: 18.9s
# 205:	total: 11s	remaining: 42.3s
# 300:	total: 15.4s	remaining: 35.8s
# 190:	total: 10.3s	remaining: 43.8s
# 316:	total: 16.2s	remaining: 35s
# 227:	total: 11.8s	remaining: 39.8s
# 188:	total: 9.91s	remaining: 42.5s
# 252:	total: 13.2s	remaining: 39s
# 690:	total: 42.1s	remaining: 18.8s
# 317:	total: 16.3s	remaining: 34.9s
# 301:	total: 15.5s	remaining: 35.7s
# 189:	total: 9.96s	remaining: 42.4s
# 191:	total: 10.4s	remaining: 43.8s
# 228:	total: 11.8s	remaining: 39.9s
# 206:	total: 11.1s	remaining: 42.4s
# 691:	total: 42.1s	remaining: 18.7s
# 253:	total: 13.3s	remaining: 39s
# 318:	total: 16.3s	remaining: 34.8s
# 302:	total: 15.5s	remaining: 35.7s
# 190:	total: 10s	remaining: 42.4s
# 207:	total: 11.1s	remaining: 42.3s
# 192:	total: 10.5s	remaining: 43.7s
# 254:	total: 13.3s	remaining: 38.9s
# 229:	total: 11.9s	remaining: 39.8s
# 692:	total: 42.2s	remaining: 18.7s
# 319:	total: 16.4s	remaining: 34.8s
# 193:	total: 10.5s	remaining: 43.6s
# 255:	total: 13.4s	remaining: 38.8s
# 208:	total: 11.2s	remaining: 42.2s
# 230:	total: 11.9s	remaining: 39.8s
# 303:	total: 15.6s	remaining: 35.7s
# 320:	total: 16.4s	remaining: 34.7s
# 191:	total: 10.1s	remaining: 42.5s
# 194:	total: 10.5s	remaining: 43.5s
# 256:	total: 13.4s	remaining: 38.7s
# 209:	total: 11.2s	remaining: 42.1s
# 693:	total: 42.2s	remaining: 18.6s
# 231:	total: 12s	remaining: 39.7s
# 321:	total: 16.5s	remaining: 34.7s
# 195:	total: 10.6s	remaining: 43.4s
# 210:	total: 11.2s	remaining: 42s
# 257:	total: 13.4s	remaining: 38.6s
# 192:	total: 10.2s	remaining: 42.4s
# 304:	total: 15.7s	remaining: 35.7s
# 232:	total: 12s	remaining: 39.6s
# 694:	total: 42.3s	remaining: 18.6s
# 322:	total: 16.5s	remaining: 34.6s
# 258:	total: 13.5s	remaining: 38.6s
# 211:	total: 11.3s	remaining: 42s
# 233:	total: 12.1s	remaining: 39.5s
# 323:	total: 16.5s	remaining: 34.5s
# 193:	total: 10.2s	remaining: 42.5s
# 695:	total: 42.4s	remaining: 18.5s
# 196:	total: 10.7s	remaining: 43.5s
# 259:	total: 13.5s	remaining: 38.5s
# 305:	total: 15.7s	remaining: 35.7s
# 696:	total: 42.4s	remaining: 18.4s
# 212:	total: 11.3s	remaining: 41.9s
# 234:	total: 12.1s	remaining: 39.5s
# 260:	total: 13.6s	remaining: 38.4s
# 324:	total: 16.6s	remaining: 34.5s
# 306:	total: 15.8s	remaining: 35.6s
# 197:	total: 10.7s	remaining: 43.4s
# 235:	total: 12.1s	remaining: 39.3s
# 325:	total: 16.6s	remaining: 34.4s
# 697:	total: 42.4s	remaining: 18.4s
# 261:	total: 13.6s	remaining: 38.3s
# 307:	total: 15.8s	remaining: 35.5s
# 213:	total: 11.4s	remaining: 41.9s
# 194:	total: 10.3s	remaining: 42.6s
# 308:	total: 15.9s	remaining: 35.5s
# 698:	total: 42.5s	remaining: 18.3s
# 326:	total: 16.7s	remaining: 34.3s
# 236:	total: 12.3s	remaining: 39.5s
# 214:	total: 11.5s	remaining: 42s
# 198:	total: 10.8s	remaining: 43.7s
# 195:	total: 10.5s	remaining: 42.9s
# 262:	total: 13.8s	remaining: 38.5s
# 699:	total: 42.6s	remaining: 18.3s
# 327:	total: 16.8s	remaining: 34.5s
# 215:	total: 11.6s	remaining: 42.1s
# 237:	total: 12.4s	remaining: 39.6s
# 309:	total: 16s	remaining: 35.7s
# 263:	total: 13.8s	remaining: 38.6s
# 196:	total: 10.6s	remaining: 43s
# 199:	total: 11s	remaining: 44s
# 328:	total: 16.9s	remaining: 34.4s
# 700:	total: 42.7s	remaining: 18.2s
# 238:	total: 12.4s	remaining: 39.6s
# 216:	total: 11.7s	remaining: 42.1s
# 264:	total: 13.9s	remaining: 38.5s
# 197:	total: 10.6s	remaining: 42.9s
# 310:	total: 16.1s	remaining: 35.7s
# 217:	total: 11.7s	remaining: 42s
# 200:	total: 11.1s	remaining: 43.9s
# 329:	total: 17s	remaining: 34.4s
# 311:	total: 16.1s	remaining: 35.6s
# 265:	total: 13.9s	remaining: 38.4s
# 701:	total: 42.8s	remaining: 18.2s
# 198:	total: 10.6s	remaining: 42.9s
# 239:	total: 12.5s	remaining: 39.6s
# 218:	total: 11.7s	remaining: 41.9s
# 330:	total: 17s	remaining: 34.3s
# 312:	total: 16.2s	remaining: 35.5s
# 240:	total: 12.5s	remaining: 39.5s
# 201:	total: 11.1s	remaining: 44s
# 702:	total: 42.8s	remaining: 18.1s
# 331:	total: 17s	remaining: 34.2s
# 219:	total: 11.8s	remaining: 41.8s
# 266:	total: 14s	remaining: 38.4s
# 199:	total: 10.7s	remaining: 42.8s
# 313:	total: 16.2s	remaining: 35.5s
# 332:	total: 17.1s	remaining: 34.2s
# 202:	total: 11.2s	remaining: 43.9s
# 220:	total: 11.8s	remaining: 41.7s
# 241:	total: 12.6s	remaining: 39.5s
# 200:	total: 10.8s	remaining: 42.7s
# 267:	total: 14s	remaining: 38.4s
# 703:	total: 42.9s	remaining: 18s
# 203:	total: 11.2s	remaining: 43.8s
# 333:	total: 17.1s	remaining: 34.1s
# 221:	total: 11.9s	remaining: 41.6s
# 704:	total: 42.9s	remaining: 18s
# 314:	total: 16.4s	remaining: 35.6s
# 268:	total: 14.2s	remaining: 38.5s
# 242:	total: 12.7s	remaining: 39.6s
# 201:	total: 10.9s	remaining: 42.9s
# 222:	total: 12s	remaining: 41.7s
# 204:	total: 11.3s	remaining: 44s
# 334:	total: 17.2s	remaining: 34.2s
# 705:	total: 43s	remaining: 17.9s
# 223:	total: 12s	remaining: 41.6s
# 269:	total: 14.2s	remaining: 38.4s
# 243:	total: 12.8s	remaining: 39.6s
# 202:	total: 10.9s	remaining: 42.9s
# 335:	total: 17.3s	remaining: 34.1s
# 706:	total: 43.1s	remaining: 17.9s
# 205:	total: 11.4s	remaining: 43.9s
# 315:	total: 16.5s	remaining: 35.7s
# 244:	total: 12.8s	remaining: 39.5s
# 224:	total: 12.1s	remaining: 41.5s
# 203:	total: 11s	remaining: 42.9s
# 336:	total: 17.3s	remaining: 34s
# 270:	total: 14.3s	remaining: 38.4s
# 225:	total: 12.1s	remaining: 41.4s
# 707:	total: 43.1s	remaining: 17.8s
# 245:	total: 12.9s	remaining: 39.5s
# 204:	total: 11s	remaining: 42.7s
# 316:	total: 16.5s	remaining: 35.6s
# 206:	total: 11.5s	remaining: 43.9s
# 708:	total: 43.2s	remaining: 17.7s
# 271:	total: 14.3s	remaining: 38.4s
# 317:	total: 16.6s	remaining: 35.5s
# 207:	total: 11.5s	remaining: 43.8s
# 205:	total: 11.1s	remaining: 42.6s
# 226:	total: 12.2s	remaining: 41.4s
# 246:	total: 12.9s	remaining: 39.4s
# 337:	total: 17.4s	remaining: 34.1s
# 709:	total: 43.2s	remaining: 17.7s
# 206:	total: 11.1s	remaining: 42.5s
# 208:	total: 11.5s	remaining: 43.7s
# 318:	total: 16.6s	remaining: 35.5s
# 272:	total: 14.4s	remaining: 38.4s
# 338:	total: 17.4s	remaining: 34s
# 227:	total: 12.2s	remaining: 41.3s
# 247:	total: 13s	remaining: 39.4s
# 207:	total: 11.1s	remaining: 42.4s
# 319:	total: 16.7s	remaining: 35.4s
# 209:	total: 11.6s	remaining: 43.6s
# 710:	total: 43.3s	remaining: 17.6s
# 248:	total: 13s	remaining: 39.3s
# 339:	total: 17.5s	remaining: 33.9s
# 228:	total: 12.3s	remaining: 41.3s
# 208:	total: 11.2s	remaining: 42.3s
# 273:	total: 14.5s	remaining: 38.3s
# 320:	total: 16.7s	remaining: 35.3s
# 249:	total: 13.1s	remaining: 39.2s
# 711:	total: 43.3s	remaining: 17.5s
# 321:	total: 16.7s	remaining: 35.2s
# 274:	total: 14.5s	remaining: 38.3s
# 210:	total: 11.7s	remaining: 43.6s
# 229:	total: 12.3s	remaining: 41.3s
# 322:	total: 16.8s	remaining: 35.1s
# 340:	total: 17.6s	remaining: 34s
# 712:	total: 43.4s	remaining: 17.5s
# 250:	total: 13.1s	remaining: 39.2s
# 211:	total: 11.7s	remaining: 43.5s
# 209:	total: 11.3s	remaining: 42.4s
# 275:	total: 14.6s	remaining: 38.3s
# 323:	total: 16.8s	remaining: 35.1s
# 230:	total: 12.4s	remaining: 41.2s
# 341:	total: 17.6s	remaining: 33.9s
# 251:	total: 13.2s	remaining: 39.1s
# 212:	total: 11.8s	remaining: 43.4s
# 210:	total: 11.3s	remaining: 42.3s
# 713:	total: 43.5s	remaining: 17.4s
# 324:	total: 16.8s	remaining: 35s
# 213:	total: 11.8s	remaining: 43.3s
# 276:	total: 14.6s	remaining: 38.2s
# 231:	total: 12.4s	remaining: 41.2s
# 714:	total: 43.5s	remaining: 17.3s
# 252:	total: 13.2s	remaining: 39s
# 214:	total: 11.8s	remaining: 43.1s
# 211:	total: 11.4s	remaining: 42.3s
# 342:	total: 17.7s	remaining: 33.9s
# 277:	total: 14.7s	remaining: 38.1s
# 232:	total: 12.5s	remaining: 41.1s
# 715:	total: 43.5s	remaining: 17.3s
# 278:	total: 14.7s	remaining: 38s
# 325:	total: 16.9s	remaining: 35s
# 253:	total: 13.3s	remaining: 39s
# 215:	total: 11.9s	remaining: 43.1s
# 343:	total: 17.8s	remaining: 33.9s
# 233:	total: 12.5s	remaining: 41s
# 212:	total: 11.4s	remaining: 42.3s
# 279:	total: 14.7s	remaining: 37.9s
# 716:	total: 43.6s	remaining: 17.2s
# 326:	total: 17s	remaining: 34.9s
# 254:	total: 13.3s	remaining: 38.9s
# 344:	total: 17.8s	remaining: 33.8s
# 234:	total: 12.6s	remaining: 40.9s
# 216:	total: 11.9s	remaining: 43s
# 280:	total: 14.8s	remaining: 37.8s
# 235:	total: 12.6s	remaining: 40.8s
# 717:	total: 43.7s	remaining: 17.1s
# 327:	total: 17s	remaining: 34.9s
# 213:	total: 11.5s	remaining: 42.4s
# 217:	total: 12s	remaining: 43s
# 255:	total: 13.4s	remaining: 38.9s
# 236:	total: 12.7s	remaining: 40.7s
# 218:	total: 12s	remaining: 42.9s
# 256:	total: 13.4s	remaining: 38.9s
# 718:	total: 43.7s	remaining: 17.1s
# 214:	total: 11.6s	remaining: 42.4s
# 219:	total: 12.1s	remaining: 42.7s
# 328:	total: 17.1s	remaining: 35s
# 719:	total: 43.8s	remaining: 17s
# 220:	total: 12.1s	remaining: 42.7s
# 237:	total: 12.8s	remaining: 40.8s
# 215:	total: 11.7s	remaining: 42.4s
# 238:	total: 12.8s	remaining: 40.8s
# 216:	total: 11.7s	remaining: 42.3s
# 720:	total: 43.9s	remaining: 17s
# 721:	total: 43.9s	remaining: 16.9s
# 217:	total: 11.7s	remaining: 42.1s
# 722:	total: 43.9s	remaining: 16.8s
# 723:	total: 43.9s	remaining: 16.7s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/4d/s5cpw8t92xbf0b9gw8j7ny2m0000gn/T/ipykernel_39869/2370854720.py in <module>
#      69     if team == 'American All-Stars':
#      70         continue
# ---> 71     res = get_catboost_and_pickle(team, df_train, df_test)
#      72     pbar.update(1)
#      73     pbar.set_description(f'{team} - {res}')
#
# /var/folders/4d/s5cpw8t92xbf0b9gw8j7ny2m0000gn/T/ipykernel_39869/2370854720.py in get_catboost_and_pickle(team_one, df_train, df_test)
#      49     # Perform GridSearchCV
#      50     grid_search = GridSearchCV(estimator=model, param_grid=params, cv=cv, scoring='accuracy', n_jobs=-1, refit=True)
# ---> 51     grid_search.fit(X_train, y_train)
#      52     test_accuracy = grid_search.score(X_test, y_test)
#      53
#
# ~/opt/anaconda3/envs/acme1/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     889                 return results
#     890
# --> 891             self._run_search(evaluate_candidates)
#     892
#     893             # multimetric is determined here because in the case of a callable
#
# ~/opt/anaconda3/envs/acme1/lib/python3.7/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1390     def _run_search(self, evaluate_candidates):
#    1391         """Search all candidates in param_grid"""
# -> 1392         evaluate_candidates(ParameterGrid(self.param_grid))
#    1393
#    1394
#
# ~/opt/anaconda3/envs/acme1/lib/python3.7/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     849                     )
#     850                     for (cand_idx, parameters), (split_idx, (train, test)) in product(
# --> 851                         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     852                     )
#     853                 )
#
# ~/opt/anaconda3/envs/acme1/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1059
#    1060             with self._backend.retrieval_context():
# -> 1061                 self.retrieve()
#    1062             # Make sure that we get a last message telling us we are done
#    1063             elapsed_time = time.time() - self._start_time
#
# ~/opt/anaconda3/envs/acme1/lib/python3.7/site-packages/joblib/parallel.py in retrieve(self)
#     936             try:
#     937                 if getattr(self._backend, 'supports_timeout', False):
# --> 938                     self._output.extend(job.get(timeout=self.timeout))
#     939                 else:
#     940                     self._output.extend(job.get())
#
# ~/opt/anaconda3/envs/acme1/lib/python3.7/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~/opt/anaconda3/envs/acme1/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     428                 return self.__get_result()
#     429
# --> 430             self._condition.wait(timeout)
#     431
#     432             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/opt/anaconda3/envs/acme1/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:
